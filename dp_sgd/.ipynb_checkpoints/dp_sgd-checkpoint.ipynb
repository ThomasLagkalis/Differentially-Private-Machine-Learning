# %% [markdown]
# ## Overview
#
# This notebook is a direct implementation of tensorflow's [tutorial on DP-SGD](https://www.tensorflow.org/responsible_ai/privacy/tutorials/classification_privacy) adjusted on the Logistic Regression model I am using.
#
# [Differential privacy](https://en.wikipedia.org/wiki/Differential_privacy) (DP) is a framework for measuring the privacy guarantees provided by an algorithm. Through the lens of differential privacy, you can design machine learning algorithms that responsibly train models on private data. Learning with differential privacy provides measurable guarantees of privacy, helping to mitigate the risk of exposing sensitive training data in machine learning. Intuitively, a model trained with differential privacy should not be affected by any single training example, or small set of training examples, in its data set. This helps mitigate the risk of exposing sensitive training data in ML.
#
# The basic idea of this approach, called differentially private stochastic gradient descent (DP-SGD), is to modify the gradients
# used in stochastic gradient descent (SGD), which lies at the core of almost all deep learning algorithms. Models trained with DP-SGD provide provable differential privacy guarantees for their input data. There are two modifications made to the vanilla SGD algorithm:
#
# 1. First, the sensitivity of each gradient needs to be bounded. In other words, you need to limit how much each individual training point sampled in a minibatch can influence gradient computations and the resulting updates applied to model parameters. This can be done by *clipping* each gradient computed on each training point.
# 2. *Random noise* is sampled and added to the clipped gradients to make it statistically impossible to know whether or not a particular data point was included in the training dataset by comparing the updates SGD applies when it operates with or without this particular data point in the training dataset.
#
# This tutorial uses [tf.keras](https://www.tensorflow.org/guide/keras) to train a convolutional neural network (CNN) to recognize handwritten digits with the DP-SGD optimizer provided by the TensorFlow Privacy library. TensorFlow Privacy provides code that wraps an existing TensorFlow optimizer to create a variant that implements DP-SGD.

# %% [markdown]
# ## Setup
#
# Begin by importing the necessary libraries:

# %%
import tensorflow as tf
import numpy as np
import tensorflow_privacy
#from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy
from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy_lib
from dp_accounting.rdp import RdpAccountant
from dp_accounting.dp_event import PoissonSampledDpEvent, GaussianDpEvent
print("Done importing...")
# Out:
# Done importing...

# %% [markdown]
# ## Load and pre-process the dataset
#
# Load the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset and prepare the data for training.

# %%
def load_dataset(n):
    train, test = tf.keras.datasets.mnist.load_data()
    train_data, train_labels = train
    test_data, test_labels = test
    
    idx = np.random.choice(len(train_data), size=n, replace=False)
    train_data = train_data[idx]
    train_labels = train_labels[idx]
    
    train_data = np.array(train_data, dtype=np.float32) / 255
    test_data = np.array(test_data, dtype=np.float32) / 255
    
    # Reshape to vectors of size 28*28 = 784
    train_data = train_data.reshape(train_data.shape[0], 28 * 28)
    test_data = test_data.reshape(test_data.shape[0], 28 * 28)
    
    
    train_labels = np.array(train_labels, dtype=np.int32)
    test_labels = np.array(test_labels, dtype=np.int32)
    
    train_labels = tf.keras.utils.to_categorical(train_labels, num_classes=10)
    test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=10)
    
    num_classes = 10
    means = np.zeros((num_classes, train_data.shape[1]), dtype=np.float32)
    
    # Convert one-hot labels back to class indices
    train_labels_int = np.argmax(train_labels, axis=1)
    
    for c in range(num_classes):
        class_samples = train_data[train_labels_int == c]
        means[c] = np.mean(class_samples, axis=0)
        
    assert train_data.min() == 0.
    assert train_data.max() == 1.
    assert test_data.min() == 0.
    assert test_data.max() == 1.

    return train_data, train_labels, test_data, test_labels, means

train_data, train_labels, test_data, test_labels, means = load_dataset(2000)
print("Train data shape: ", train_data.shape)
print("Test data shape: ", test_data.shape)
print("Means shape:", means.shape)  # (10, 784)
# Out:
# Train data shape:  (2000, 784)
# Test data shape:  (10000, 784)
# Means shape: (10, 784)

# %% [markdown]
# ## Define the hyperparameters
# Set learning model hyperparamter values.
#
# DP-SGD has three privacy-specific hyperparameters and one existing hyperamater that you must tune:
#
# 1. `l2_norm_clip` (float) - The maximum Euclidean (L2) norm of each gradient that is applied to update model parameters. This hyperparameter is used to bound the optimizer's sensitivity to individual training points.
# 2. `noise_multiplier` (float) - The amount of noise sampled and added to gradients during training. Generally, more noise results in better privacy (often, but not necessarily, at the expense of lower utility).
# 3.   `microbatches` (int) - Each batch of data is split in smaller units called microbatches. By default, each microbatch should contain a single training example. This allows us to clip gradients on a per-example basis rather than after they have been averaged across the minibatch. This in turn decreases the (negative) effect of clipping on signal found in the gradient and typically maximizes utility. However, computational overhead can be reduced by increasing the size of microbatches to include more than one training examples. The average gradient across these multiple training examples is then clipped. The total number of examples consumed in a batch, i.e., one step of gradient descent, remains the same. The number of microbatches should evenly divide the batch size.
# 4. `learning_rate` (float) - This hyperparameter already exists in vanilla SGD. The higher the learning rate, the more each update matters. If the updates are noisy (such as when the additive noise is large compared to the clipping threshold), a low learning rate may help the training procedure converge.
#
# Use the hyperparameter values below to obtain a reasonably accurate model (95% test accuracy):

# %%
epochs = 3
batch_size = 250
l2_norm_clip = 1.5
noise_multiplier = 1.3
num_microbatches = 250
learning_rate = 0.25

if batch_size % num_microbatches != 0:
  raise ValueError('Batch size should be an integer multiple of the number of microbatches')

# %% [markdown]
# ## Build the model
# Input layer of dimension $d=28*28=784$ and a linear layer which outputs the logits.

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),   # or (28*28,)
        tf.keras.layers.Dense(10)              # logits, no activation
    ])
    return model
model = build_model()

# %% [markdown]
# Define the optimizer and loss function for the learning model. Compute the loss as a vector of losses per-example rather than as the mean over a minibatch to support gradient manipulation over each training point.

# %%
optimizer = tensorflow_privacy.DPKerasSGDOptimizer(
    l2_norm_clip=l2_norm_clip,
    noise_multiplier=noise_multiplier,
    num_microbatches=num_microbatches,
    learning_rate=learning_rate)

loss = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, reduction=tf.losses.Reduction.NONE)

# %% [markdown]
# ## Train the model

# %%
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

model.fit(train_data, train_labels,
          epochs=epochs,
          validation_data=(test_data, test_labels),
          batch_size=batch_size)
# Out:
# Epoch 1/3
# 8/8 [==============================] - 1s 67ms/step - loss: 2.1897 - accuracy: 0.2525 - val_loss: 2.0092 - val_accuracy: 0.3720
# Epoch 2/3
# 8/8 [==============================] - 0s 39ms/step - loss: 1.8899 - accuracy: 0.4350 - val_loss: 1.7397 - val_accuracy: 0.5166
# Epoch 3/3
# 8/8 [==============================] - 0s 36ms/step - loss: 1.6459 - accuracy: 0.5485 - val_loss: 1.5263 - val_accuracy: 0.6165

# %% [markdown]
# ## Measure the differential privacy guarantee
#
# Perform a privacy analysis to measure the DP guarantee achieved by a training algorithm. Knowing the level of DP achieved enables the objective comparison of two training runs to determine which of the two is more privacy-preserving. At a high level, the privacy analysis measures how much a potential adversary can improve their guess about properties of any individual training point by observing the outcome of the training procedure (e.g., model updates and parameters).
#
# This guarantee is sometimes referred to as the **privacy budget**. A lower privacy budget bounds more tightly an adversary's ability to improve their guess. This ensures a stronger privacy guarantee. Intuitively, this is because it is harder for a single training point to affect the outcome of learning: for instance, the information contained in the training point cannot be memorized by the ML algorithm and the privacy of the individual who contributed this training point to the dataset is preserved.
#
# In this tutorial, the privacy analysis is performed in the framework of Rényi Differential Privacy (RDP), which is a relaxation of pure DP based on [this paper](https://arxiv.org/abs/1702.07476) that is particularly well suited for DP-SGD.
#
# Two metrics are used to express the DP guarantee of an ML algorithm:
#
# 1.   Delta ($\delta$) - Bounds the probability of the privacy guarantee not holding. A rule of thumb is to set it to be less than the inverse of the size of the training dataset. In this tutorial, it is set to **10^-5** as the MNIST dataset has 60,000 training points.
# 2.   Epsilon ($\epsilon$) - This is the privacy budget. It measures the strength of the privacy guarantee by bounding how much the probability of a particular model output can vary by including (or excluding) a single training point. A smaller value for $\epsilon$ implies a better privacy guarantee. However, the $\epsilon$ value is only an upper bound and a large value could still mean good privacy in practice.
#
# Tensorflow Privacy provides a tool, `compute_dp_sgd_privacy`, to compute the value of $\epsilon$ given a fixed value of $\delta$ and the following hyperparameters from the training process:
#
# 1.   The total number of points in the training data, `n`.
# 2. The `batch_size`.
# 3.   The `noise_multiplier`.
# 4. The number of `epochs` of training.

# %%
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    steps = (n // batch_size) * epochs

    # Build the DP-SGD event
    sample_rate = batch_size / n
    accountant = RdpAccountant()
    event = PoissonSampledDpEvent(
        sampling_probability=sample_rate,
        event=GaussianDpEvent(noise_multiplier)
    )

    # Accumulate privacy events
    accountant.compose(event, count=steps)

    # Compute epsilon
    return accountant.get_epsilon(delta)

# %%
epsilon = compute_epsilon(
    n=train_data.shape[0],
    batch_size=batch_size,
    noise_multiplier=noise_multiplier,
    epochs=epochs,
    delta=1e-5
)


print("Epsilon =", epsilon)
# Out:
# Epsilon = 3.339889050569681

# %%
compute_dp_sgd_privacy_lib.compute_dp_sgd_privacy(n=train_data.shape[0],
                                 
                                                  batch_size=batch_size,
                                              noise_multiplier=noise_multiplier,
                                              epochs=epochs,
                                              delta=1e-5)
# Out:
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# (3.372610819732178, 5.0)

# %%
compute_dp_sgd_privacy_lib.compute_dp_sgd_privacy_statement(number_of_examples=train_data.shape[0],
                                              batch_size=batch_size,
                                              noise_multiplier=noise_multiplier,
                                              num_epochs=epochs,
                                              delta=1e-5)
# Out:
# 'DP-SGD performed over 2000 examples with 250 examples per iteration, noise\nmultiplier 1.3 for 3 epochs with microbatching, and no bound on number of\nexamples per user.\n\nThis privacy guarantee protects the release of all model checkpoints in addition\nto the final model.\n\nExample-level DP with add-or-remove-one adjacency at delta = 1e-05 computed with\nRDP accounting:\n    Epsilon with each example occurring once per epoch:        15.311\n    Epsilon assuming Poisson sampling (*):                     12.823\n\nNo user-level privacy guarantee is possible without a bound on the number of\nexamples per user.\n\n(*) Poisson sampling is not usually done in training pipelines, but assuming\nthat the data was randomly shuffled, it is believed that the actual epsilon\nshould be closer to this value than the conservative assumption of an arbitrary\ndata order.\n'

# %% [markdown]
# # Experiments for different $\epsilon$ values
# Next, we need to find the $\sigma$ value that yields the target $\epsilon$. Since $\epsilon(\sigma)$ is a monotonically decreasing function, we implement a binary search to find the corresponding $\sigma$.
#
# ## Setup
#
# * **learning rate**: 0.25
# * **epochs**: 1st senario with 3 epochs and 2nd with 100 epochs. At the compartison with output perturbation we had 10 epochs.
# * **batch size**: 250
# * **microbatches**: 250
# * **delta**: $10^{-5}$
# * **training dataset size** $n$: 2000

# %%
def find_sigma_for_target_epsilon(target_eps, steps, delta,
                                 sigma_min=0.1, sigma_max=100,
                                 tol=0.01, max_iter=40):

    for _ in range(max_iter):
        

        sigma_mid = (sigma_min + sigma_max)/2
        eps_mid = compute_epsilon(n=train_data.shape[0], batch_size=batch_size, noise_multiplier=sigma_mid,
                                  epochs=epochs, delta=1e-5
                                 )
        #print(f"eps_mid = {eps_mid}, sigma_min = {sigma_min}, sigma_max = {sigma_max}")
        if abs(eps_mid - target_eps) < tol:
            return sigma_mid

        if eps_mid > target_eps:
            sigma_min = sigma_mid
        else:
            sigma_max = sigma_mid

    return sigma_mid

sigma = find_sigma_for_target_epsilon(0.1, epochs, 1e-5)
print(sigma)
# Out:
# 21.953125

# %%
def reconstruction_tf(
    model,
    label,
    class_mean=None,
    test_data=None,
    test_labels=None,
    H=28,
    W=28,
    step_size=0.1,
    tv_weight=0.01,
    init_mode="zeros",
    show_cost=False,
    verbose=False,
    thres=1e-5,
    max_iters=10000
):
    """
    TensorFlow MI-Face reconstruction attack
    """

    if verbose:
        print(f"Beginning reconstruction attack, target label = {label}")

    # -----------------------
    # Test accuracy 
    # -----------------------
    acc = -1.0
    if test_data is not None and test_labels is not None:
        logits = model(test_data, training=False)
        preds = tf.argmax(logits, axis=1)
        acc = tf.reduce_mean(
            tf.cast(preds == tf.argmax(test_labels, axis=1), tf.float32)
        ).numpy()

        if verbose:
            print(f"Test accuracy: {acc:.4f}")

    # -----------------------
    # Initialize image
    # -----------------------
    if init_mode == "zeros":
        x_img = tf.Variable(tf.zeros([1, H * W], dtype=tf.float32))
    elif init_mode == "ones":
        x_img = tf.Variable(tf.ones([1, H * W], dtype=tf.float32))
    elif init_mode == "noise":
        x_img = tf.Variable(tf.random.normal([1, H * W], stddev=0.1))
    elif init_mode == "weights":
        w = model.trainable_variables[0][:, label]
        x_img = tf.Variable(tf.reshape(w, [1, H * W]))
    else:
        x_img = tf.Variable(tf.zeros([1, H * W], dtype=tf.float32))

    optimizer = tf.keras.optimizers.SGD(learning_rate=step_size)

    best_img = None
    best_prob = -1.0
    loss_list = []

    iters = 0

    # -----------------------
    # Optimization loop
    # -----------------------
    while True:
        iters += 1
        x_prev = tf.identity(x_img)

        with tf.GradientTape() as tape:
            logits = model(x_img, training=False)
            probs = tf.nn.softmax(logits, axis=1)

            loss = 1.0 - probs[0, label] 

        grads = tape.gradient(loss, [x_img])
        optimizer.apply_gradients(zip(grads, [x_img]))

        loss_list.append(loss.numpy())

        # -----------------------
        # Track best reconstruction
        # -----------------------
        p = probs[0, label].numpy()
        if p > best_prob:
            best_prob = p
            best_img = tf.identity(x_img)

        # -----------------------
        # Convergence check
        # -----------------------
        num = tf.norm(x_prev - x_img)
        denom = tf.norm(x_img) + 1e-12
        thres_val = (num / denom).numpy()

        if verbose and iters % 1000 == 0:
            print(f"Iter {iters}, threshold={thres_val:.6e}, prob={p:.4f}")

        if thres_val < thres or iters >= max_iters:
            break


    if verbose:
        print(f"Finished in {iters} iterations")

    return best_img, best_prob, loss_list, acc

# %%
import math

# Helper function
def angle_between(u, v, eps=1e-7):
    u = np.array(u, dtype=np.float64)
    v = np.array(v, dtype=np.float64)

    norm_u = np.linalg.norm(u)
    norm_v = np.linalg.norm(v)

    if norm_u < eps and norm_v < eps:
        return 0.0, 0.0
    elif norm_u < eps or norm_v < eps:
        return np.pi / 2, 90.0

    cos_theta = np.dot(u, v) / (norm_u * norm_v)

    # Numerical safety: clip before arccos
    cos_theta = np.clip(cos_theta, -1.0, 1.0)

    angle_rad = np.arccos(cos_theta)
    angle_deg = np.degrees(angle_rad)
    return angle_rad, angle_deg

def perform_experiment(epsilon, delta=1e-5, learning_rate=0.25, num_microbatches=250, l2_norm_clip=1.5, epochs=3, batch_size=250):
    '''
    Performs an expiriment for a specific privacy budget.
    Calculates and returns the accuracy and the angle of recostruction.
    '''
    print(f'Performing experiment for epsilon = {epsilon}')
    model = build_model()
    noise_multiplier = find_sigma_for_target_epsilon(epsilon, epochs, delta)
    optimizer = tensorflow_privacy.DPKerasSGDOptimizer(l2_norm_clip=l2_norm_clip,
                                                       noise_multiplier=noise_multiplier,
                                                       num_microbatches=num_microbatches, 
                                                       learning_rate=learning_rate
                                                      )

    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True, 
                                                   reduction=tf.losses.Reduction.NONE
                                                  )
    # Train the model
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              validation_data=(test_data, test_labels),
              batch_size=batch_size)

    # Calculate the accuracy on validation set.
    _, val_acc = model.evaluate(test_data, test_labels, batch_size=batch_size, verbose=0)
    
    # Calculate the angle.
    cum_angle = 0
    for label in range(10):
        rec_img, best_conf, loss_list, _ = reconstruction_tf(model, label, H=28, W=28,
                                                                    init_mode="weights", thres=1e-4, verbose=False
                                                                    )

        rec_img = np.array(rec_img)[0,:]
        vmin = np.min(rec_img)
        vmax = np.max(rec_img)
        rec_img = (rec_img - vmin)/(vmax - vmin)

        vmin = np.min(means[label])
        vmax = np.max(means[label])
        means[label] = (means[label] - vmin)/(vmax - vmin)
        
        angle, _ = angle_between(rec_img, means[label])
        
        cum_angle += math.sin(angle)
        
    return val_acc, cum_angle/10

    
acc, angle = perform_experiment(10)
print("Accuracy: ", acc)
print("Angle: ", angle)
# Out:
# Performing experiment for epsilon = 10
# Epoch 1/3
# 8/8 [==============================] - 1s 52ms/step - loss: 2.2423 - accuracy: 0.1700 - val_loss: 2.0440 - val_accuracy: 0.3500
# Epoch 2/3
# 8/8 [==============================] - 0s 34ms/step - loss: 1.9113 - accuracy: 0.4305 - val_loss: 1.7537 - val_accuracy: 0.5371
# Epoch 3/3
# 8/8 [==============================] - 0s 35ms/step - loss: 1.6560 - accuracy: 0.5740 - val_loss: 1.5249 - val_accuracy: 0.6283
# Accuracy:  0.6283000111579895
# Angle:  0.8409577031219653

# %%
import matplotlib.pyplot as plt

#eps_arr = np.load('./data/epsilon_arr_gaussian_delta1e-5.npy')
eps_arr = [0.01, 0.1, 0.5, 1, 5, 10, 50]

acc_dpsgd, angles_dpsgd = [], []
iters = 10

for eps in eps_arr:
    acc, angle = 0, 0
    for _ in range(iters):
        acc_tmp, angle_tmp = perform_experiment(eps, epochs=100)
        acc += acc_tmp
        angle += angle_tmp
    acc_dpsgd.append(acc/iters)
    angles_dpsgd.append(angle/iters)


# Plot the results.
plt.rcParams.update({'font.size': 28})
fig, ax1 = plt.subplots()
fig.set_size_inches(16, 9)
color = 'tab:red'
ax1.set_xlabel(r'$\epsilon_p$')
ax1.set_ylabel('Accuracy', color=color)
ax1.semilogx(eps_arr, acc_dpsgd, color=color, linestyle='--', marker='x', linewidth=3, label='DP-SGD')
#ax1.plot(eps_arr, acc_output, color=color, linestyle='-.', marker='o',linewidth=3, label='output')
#ax1.plot(eps_arr, acc_non_private, color=color, linestyle='-',linewidth=3, label='non private')
ax1.tick_params(axis='y', labelcolor=color)
        
ax2 = ax1.twinx()
        
color = 'tab:blue'
ax2.set_ylabel(r'$Sine(\hat{x}, \mu)$', color=color)
ax2.semilogx(eps_arr, angles_dpsgd, color=color, linestyle='--', linewidth=3, marker='x', label='DP-SGD')
#ax2.plot(eps_arr, angles_output, color=color, linestyle='-.', linewidth=3, marker='o', label='output')
#ax2.plot(eps_arr, angles_non_private, color=color, linestyle='-', linewidth=3, label='non private')
ax2.tick_params(axis='y', labelcolor=color)

#fig.tight_layout()

plt.title(fr"Angle and accuracy for different $\epsilon_p$")
plt.legend(loc='center right')
plt.show()
# Out:
# Performing experiment for epsilon = 0.01
# Epoch 1/100
# 8/8 [==============================] - 1s 55ms/step - loss: 4.3714 - accuracy: 0.0995 - val_loss: 6.6229 - val_accuracy: 0.0927
# Epoch 2/100
# 8/8 [==============================] - 0s 38ms/step - loss: 6.2633 - accuracy: 0.1230 - val_loss: 6.4794 - val_accuracy: 0.1420
# Epoch 3/100
# 8/8 [==============================] - 0s 37ms/step - loss: 7.2282 - accuracy: 0.1500 - val_loss: 8.1284 - val_accuracy: 0.1511
# Epoch 4/100
# 8/8 [==============================] - 0s 39ms/step - loss: 8.7505 - accuracy: 0.1725 - val_loss: 9.5270 - val_accuracy: 0.1641
# Epoch 5/100
# 8/8 [==============================] - 0s 36ms/step - loss: 9.1860 - accuracy: 0.1680 - val_loss: 9.9135 - val_accuracy: 0.1511
# Epoch 6/100
# 8/8 [==============================] - 0s 37ms/step - loss: 9.7158 - accuracy: 0.1545 - val_loss: 9.8874 - val_accuracy: 0.1437
# Epoch 7/100
# 8/8 [==============================] - 0s 36ms/step - loss: 10.2589 - accuracy: 0.1515 - val_loss: 10.3038 - val_accuracy: 0.1424
# Epoch 8/100
# 8/8 [==============================] - 0s 36ms/step - loss: 10.1506 - accuracy: 0.1425 - val_loss: 10.7537 - val_accuracy: 0.1422
# Epoch 9/100
# 8/8 [==============================] - 0s 36ms/step - loss: 10.9025 - accuracy: 0.1360 - val_loss: 11.5686 - val_accuracy: 0.1221
# Epoch 10/100
# 8/8 [==============================] - 0s 36ms/step - loss: 11.1552 - accuracy: 0.1405 - val_loss: 11.6017 - val_accuracy: 0.1493
# Epoch 11/100
# 8/8 [==============================] - 0s 35ms/step - loss: 12.1171 - accuracy: 0.1785 - val_loss: 13.4617 - val_accuracy: 0.1762
# Epoch 12/100
# 8/8 [==============================] - 0s 36ms/step - loss: 12.3159 - accuracy: 0.1870 - val_loss: 12.3676 - val_accuracy: 0.1815
# Epoch 13/100
# 8/8 [==============================] - 0s 34ms/step - loss: 13.1825 - accuracy: 0.1920 - val_loss: 14.0988 - val_accuracy: 0.1885
# Epoch 14/100
# 8/8 [==============================] - 0s 35ms/step - loss: 13.4488 - accuracy: 0.1875 - val_loss: 13.1137 - val_accuracy: 0.1907
# Epoch 15/100
# 8/8 [==============================] - 0s 34ms/step - loss: 13.3173 - accuracy: 0.1960 - val_loss: 13.2102 - val_accuracy: 0.2100
# Epoch 16/100
# 8/8 [==============================] - 0s 34ms/step - loss: 12.9768 - accuracy: 0.2220 - val_loss: 12.7555 - val_accuracy: 0.2382
# Epoch 17/100
# 8/8 [==============================] - 0s 35ms/step - loss: 13.4104 - accuracy: 0.2520 - val_loss: 13.6438 - val_accuracy: 0.2401
# Epoch 18/100
# 8/8 [==============================] - 0s 37ms/step - loss: 13.0002 - accuracy: 0.2480 - val_loss: 12.3849 - val_accuracy: 0.2512
# Epoch 19/100
# 8/8 [==============================] - 0s 36ms/step - loss: 12.2067 - accuracy: 0.2555 - val_loss: 11.9665 - val_accuracy: 0.2553
# Epoch 20/100
# 8/8 [==============================] - 0s 36ms/step - loss: 12.4810 - accuracy: 0.2675 - val_loss: 13.2383 - val_accuracy: 0.2525
# Epoch 21/100
# 8/8 [==============================] - 0s 38ms/step - loss: 13.6331 - accuracy: 0.2635 - val_loss: 13.9948 - val_accuracy: 0.2589
# Epoch 22/100
# 8/8 [==============================] - 0s 37ms/step - loss: 14.0855 - accuracy: 0.2705 - val_loss: 13.5671 - val_accuracy: 0.2769
# Epoch 23/100
# 8/8 [==============================] - 0s 37ms/step - loss: 14.0557 - accuracy: 0.2730 - val_loss: 14.2896 - val_accuracy: 0.2671
# Epoch 24/100
# 8/8 [==============================] - 0s 36ms/step - loss: 14.9757 - accuracy: 0.2505 - val_loss: 15.2658 - val_accuracy: 0.2296
# Epoch 25/100
# 8/8 [==============================] - 0s 36ms/step - loss: 15.8614 - accuracy: 0.2190 - val_loss: 15.7738 - val_accuracy: 0.2105
# Epoch 26/100
# 8/8 [==============================] - 0s 35ms/step - loss: 16.2540 - accuracy: 0.2040 - val_loss: 16.3465 - val_accuracy: 0.1792
# Epoch 27/100
# 8/8 [==============================] - 0s 39ms/step - loss: 16.6597 - accuracy: 0.1880 - val_loss: 16.6257 - val_accuracy: 0.1877
# Epoch 28/100
# 8/8 [==============================] - 0s 37ms/step - loss: 16.8737 - accuracy: 0.1800 - val_loss: 17.2027 - val_accuracy: 0.1738
# Epoch 29/100
# 8/8 [==============================] - 0s 36ms/step - loss: 18.0151 - accuracy: 0.1670 - val_loss: 17.9765 - val_accuracy: 0.1809
# Epoch 30/100
# 8/8 [==============================] - 0s 37ms/step - loss: 18.3582 - accuracy: 0.1810 - val_loss: 18.2977 - val_accuracy: 0.1872
# Epoch 31/100
# 8/8 [==============================] - 0s 35ms/step - loss: 18.7624 - accuracy: 0.1855 - val_loss: 18.9422 - val_accuracy: 0.1820
# Epoch 32/100
# 8/8 [==============================] - 0s 35ms/step - loss: 19.0970 - accuracy: 0.2000 - val_loss: 19.2850 - val_accuracy: 0.1928
# Epoch 33/100
# 8/8 [==============================] - 0s 36ms/step - loss: 19.1513 - accuracy: 0.2150 - val_loss: 19.1784 - val_accuracy: 0.2236
# Epoch 34/100
# 8/8 [==============================] - 0s 35ms/step - loss: 19.3532 - accuracy: 0.2200 - val_loss: 19.6347 - val_accuracy: 0.2268
# Epoch 35/100
# 8/8 [==============================] - 0s 35ms/step - loss: 19.6786 - accuracy: 0.2315 - val_loss: 20.1430 - val_accuracy: 0.2196
# Epoch 36/100
# 8/8 [==============================] - 0s 37ms/step - loss: 19.8861 - accuracy: 0.2375 - val_loss: 19.5778 - val_accuracy: 0.2265
# Epoch 37/100
# 8/8 [==============================] - 0s 35ms/step - loss: 20.1495 - accuracy: 0.2270 - val_loss: 20.2293 - val_accuracy: 0.2171
# Epoch 38/100
# 8/8 [==============================] - 0s 44ms/step - loss: 20.4781 - accuracy: 0.2180 - val_loss: 20.8619 - val_accuracy: 0.2207
# Epoch 39/100
# 8/8 [==============================] - 0s 31ms/step - loss: 21.0563 - accuracy: 0.2205 - val_loss: 21.3225 - val_accuracy: 0.2151
# Epoch 40/100
# 8/8 [==============================] - 0s 35ms/step - loss: 20.6136 - accuracy: 0.2235 - val_loss: 20.5169 - val_accuracy: 0.2202
# Epoch 41/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.7948 - accuracy: 0.2180 - val_loss: 20.7689 - val_accuracy: 0.2156
# Epoch 42/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.5652 - accuracy: 0.2120 - val_loss: 20.5859 - val_accuracy: 0.2161
# Epoch 43/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.5560 - accuracy: 0.2130 - val_loss: 21.1656 - val_accuracy: 0.2231
# Epoch 44/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.8292 - accuracy: 0.2195 - val_loss: 20.2962 - val_accuracy: 0.2371
# Epoch 45/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.6954 - accuracy: 0.2390 - val_loss: 21.0655 - val_accuracy: 0.2401
# Epoch 46/100
# 8/8 [==============================] - 0s 27ms/step - loss: 21.2818 - accuracy: 0.2300 - val_loss: 21.7898 - val_accuracy: 0.2146
# Epoch 47/100
# 8/8 [==============================] - 0s 30ms/step - loss: 22.0772 - accuracy: 0.2040 - val_loss: 21.8465 - val_accuracy: 0.2160
# Epoch 48/100
# 8/8 [==============================] - 0s 29ms/step - loss: 22.2346 - accuracy: 0.2055 - val_loss: 21.9207 - val_accuracy: 0.2108
# Epoch 49/100
# 8/8 [==============================] - 0s 29ms/step - loss: 22.1333 - accuracy: 0.2000 - val_loss: 21.9867 - val_accuracy: 0.2039
# Epoch 50/100
# 8/8 [==============================] - 0s 30ms/step - loss: 22.2341 - accuracy: 0.2015 - val_loss: 22.5951 - val_accuracy: 0.1965
# Epoch 51/100
# 8/8 [==============================] - 0s 31ms/step - loss: 22.7565 - accuracy: 0.1965 - val_loss: 23.1170 - val_accuracy: 0.2036
# Epoch 52/100
# 8/8 [==============================] - 0s 29ms/step - loss: 23.6850 - accuracy: 0.2045 - val_loss: 24.4956 - val_accuracy: 0.1925
# Epoch 53/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.7468 - accuracy: 0.2090 - val_loss: 25.4060 - val_accuracy: 0.1852
# Epoch 54/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.9054 - accuracy: 0.1965 - val_loss: 25.2202 - val_accuracy: 0.1807
# Epoch 55/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.7587 - accuracy: 0.2010 - val_loss: 25.7174 - val_accuracy: 0.1818
# Epoch 56/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.3188 - accuracy: 0.2080 - val_loss: 25.7951 - val_accuracy: 0.1989
# Epoch 57/100
# 8/8 [==============================] - 0s 30ms/step - loss: 25.3620 - accuracy: 0.2135 - val_loss: 26.0256 - val_accuracy: 0.2092
# Epoch 58/100
# 8/8 [==============================] - 0s 33ms/step - loss: 25.1129 - accuracy: 0.2155 - val_loss: 25.8008 - val_accuracy: 0.2061
# Epoch 59/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.2863 - accuracy: 0.2200 - val_loss: 26.2463 - val_accuracy: 0.2103
# Epoch 60/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.6993 - accuracy: 0.2210 - val_loss: 25.5933 - val_accuracy: 0.2140
# Epoch 61/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.6295 - accuracy: 0.2175 - val_loss: 26.1484 - val_accuracy: 0.1971
# Epoch 62/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.0264 - accuracy: 0.2140 - val_loss: 25.1138 - val_accuracy: 0.2084
# Epoch 63/100
# 8/8 [==============================] - 0s 33ms/step - loss: 24.4440 - accuracy: 0.2235 - val_loss: 24.8331 - val_accuracy: 0.2052
# Epoch 64/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.0807 - accuracy: 0.2275 - val_loss: 24.1314 - val_accuracy: 0.2170
# Epoch 65/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.6160 - accuracy: 0.2185 - val_loss: 25.3243 - val_accuracy: 0.1931
# Epoch 66/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.0195 - accuracy: 0.1990 - val_loss: 25.4272 - val_accuracy: 0.1939
# Epoch 67/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.9845 - accuracy: 0.2035 - val_loss: 25.0144 - val_accuracy: 0.2006
# Epoch 68/100
# 8/8 [==============================] - 0s 31ms/step - loss: 24.5219 - accuracy: 0.2175 - val_loss: 24.8340 - val_accuracy: 0.2024
# Epoch 69/100
# 8/8 [==============================] - 0s 30ms/step - loss: 25.1163 - accuracy: 0.2120 - val_loss: 25.7163 - val_accuracy: 0.1961
# Epoch 70/100
# 8/8 [==============================] - 0s 31ms/step - loss: 24.9913 - accuracy: 0.2115 - val_loss: 25.0462 - val_accuracy: 0.2033
# Epoch 71/100
# 8/8 [==============================] - 0s 31ms/step - loss: 24.8386 - accuracy: 0.2170 - val_loss: 25.6052 - val_accuracy: 0.2010
# Epoch 72/100
# 8/8 [==============================] - 0s 33ms/step - loss: 25.2215 - accuracy: 0.2170 - val_loss: 24.8508 - val_accuracy: 0.1974
# Epoch 73/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.5110 - accuracy: 0.2160 - val_loss: 24.5113 - val_accuracy: 0.1951
# Epoch 74/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.9506 - accuracy: 0.2225 - val_loss: 24.2640 - val_accuracy: 0.2042
# Epoch 75/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.3146 - accuracy: 0.2260 - val_loss: 24.7969 - val_accuracy: 0.2143
# Epoch 76/100
# 8/8 [==============================] - 0s 27ms/step - loss: 24.4582 - accuracy: 0.2345 - val_loss: 24.5536 - val_accuracy: 0.2206
# Epoch 77/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.0556 - accuracy: 0.2520 - val_loss: 25.0753 - val_accuracy: 0.2264
# Epoch 78/100
# 8/8 [==============================] - 0s 31ms/step - loss: 24.4573 - accuracy: 0.2600 - val_loss: 25.1992 - val_accuracy: 0.2316
# Epoch 79/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.4980 - accuracy: 0.2605 - val_loss: 24.9127 - val_accuracy: 0.2366
# Epoch 80/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.4274 - accuracy: 0.2510 - val_loss: 24.2775 - val_accuracy: 0.2353
# Epoch 81/100
# 8/8 [==============================] - 0s 28ms/step - loss: 23.9706 - accuracy: 0.2630 - val_loss: 23.7733 - val_accuracy: 0.2439
# Epoch 82/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.8157 - accuracy: 0.2550 - val_loss: 24.1168 - val_accuracy: 0.2325
# Epoch 83/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.1842 - accuracy: 0.2505 - val_loss: 24.7307 - val_accuracy: 0.2294
# Epoch 84/100
# 8/8 [==============================] - 0s 28ms/step - loss: 24.7271 - accuracy: 0.2470 - val_loss: 25.3554 - val_accuracy: 0.2175
# Epoch 85/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.3864 - accuracy: 0.2515 - val_loss: 23.9709 - val_accuracy: 0.2332
# Epoch 86/100
# 8/8 [==============================] - 0s 28ms/step - loss: 23.2392 - accuracy: 0.2570 - val_loss: 22.9932 - val_accuracy: 0.2480
# Epoch 87/100
# 8/8 [==============================] - 0s 27ms/step - loss: 23.2723 - accuracy: 0.2575 - val_loss: 23.4403 - val_accuracy: 0.2485
# Epoch 88/100
# 8/8 [==============================] - 0s 32ms/step - loss: 23.1726 - accuracy: 0.2715 - val_loss: 24.0080 - val_accuracy: 0.2482
# Epoch 89/100
# 8/8 [==============================] - 0s 32ms/step - loss: 23.1820 - accuracy: 0.2655 - val_loss: 23.4076 - val_accuracy: 0.2563
# Epoch 90/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.2923 - accuracy: 0.2715 - val_loss: 24.2989 - val_accuracy: 0.2523
# Epoch 91/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.5712 - accuracy: 0.2785 - val_loss: 24.6575 - val_accuracy: 0.2591
# Epoch 92/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.9783 - accuracy: 0.2760 - val_loss: 24.0697 - val_accuracy: 0.2638
# Epoch 93/100
# 8/8 [==============================] - 0s 29ms/step - loss: 23.7218 - accuracy: 0.2735 - val_loss: 23.9318 - val_accuracy: 0.2673
# Epoch 94/100
# 8/8 [==============================] - 0s 29ms/step - loss: 23.7771 - accuracy: 0.2770 - val_loss: 23.9111 - val_accuracy: 0.2680
# Epoch 95/100
# 8/8 [==============================] - 0s 28ms/step - loss: 23.6600 - accuracy: 0.2720 - val_loss: 24.9930 - val_accuracy: 0.2595
# Epoch 96/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.9140 - accuracy: 0.2665 - val_loss: 23.7404 - val_accuracy: 0.2662
# Epoch 97/100
# 8/8 [==============================] - 0s 31ms/step - loss: 23.6580 - accuracy: 0.2650 - val_loss: 24.6174 - val_accuracy: 0.2488
# Epoch 98/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.3669 - accuracy: 0.2545 - val_loss: 25.2326 - val_accuracy: 0.2417
# Epoch 99/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.7962 - accuracy: 0.2450 - val_loss: 25.5824 - val_accuracy: 0.2401
# Epoch 100/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.8902 - accuracy: 0.2470 - val_loss: 24.9470 - val_accuracy: 0.2531
# Performing experiment for epsilon = 0.01
# Epoch 1/100
# 8/8 [==============================] - 1s 43ms/step - loss: 4.1797 - accuracy: 0.0935 - val_loss: 5.2008 - val_accuracy: 0.1388
# Epoch 2/100
# 8/8 [==============================] - 0s 29ms/step - loss: 5.3454 - accuracy: 0.1390 - val_loss: 6.1539 - val_accuracy: 0.1378
# Epoch 3/100
# 8/8 [==============================] - 0s 31ms/step - loss: 6.0977 - accuracy: 0.1825 - val_loss: 6.7965 - val_accuracy: 0.1648
# Epoch 4/100
# 8/8 [==============================] - 0s 29ms/step - loss: 6.9413 - accuracy: 0.1915 - val_loss: 7.3652 - val_accuracy: 0.1943
# Epoch 5/100
# 8/8 [==============================] - 0s 33ms/step - loss: 7.3749 - accuracy: 0.2130 - val_loss: 7.3001 - val_accuracy: 0.2244
# Epoch 6/100
# 8/8 [==============================] - 0s 29ms/step - loss: 7.7296 - accuracy: 0.2180 - val_loss: 8.3862 - val_accuracy: 0.1914
# Epoch 7/100
# 8/8 [==============================] - 0s 29ms/step - loss: 9.1894 - accuracy: 0.1725 - val_loss: 9.5973 - val_accuracy: 0.1656
# Epoch 8/100
# 8/8 [==============================] - 0s 30ms/step - loss: 9.2032 - accuracy: 0.1855 - val_loss: 9.9486 - val_accuracy: 0.1549
# Epoch 9/100
# 8/8 [==============================] - 0s 29ms/step - loss: 10.2683 - accuracy: 0.1565 - val_loss: 11.8240 - val_accuracy: 0.1384
# Epoch 10/100
# 8/8 [==============================] - 0s 29ms/step - loss: 11.4228 - accuracy: 0.1525 - val_loss: 11.3006 - val_accuracy: 0.1637
# Epoch 11/100
# 8/8 [==============================] - 0s 30ms/step - loss: 11.1966 - accuracy: 0.1740 - val_loss: 11.3794 - val_accuracy: 0.1880
# Epoch 12/100
# 8/8 [==============================] - 0s 28ms/step - loss: 11.4355 - accuracy: 0.2060 - val_loss: 12.3129 - val_accuracy: 0.1918
# Epoch 13/100
# 8/8 [==============================] - 0s 30ms/step - loss: 12.6023 - accuracy: 0.2010 - val_loss: 13.7804 - val_accuracy: 0.2061
# Epoch 14/100
# 8/8 [==============================] - 0s 29ms/step - loss: 13.6726 - accuracy: 0.1855 - val_loss: 13.9463 - val_accuracy: 0.1663
# Epoch 15/100
# 8/8 [==============================] - 0s 31ms/step - loss: 14.2628 - accuracy: 0.1625 - val_loss: 15.1323 - val_accuracy: 0.1545
# Epoch 16/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.5227 - accuracy: 0.1470 - val_loss: 15.2216 - val_accuracy: 0.1485
# Epoch 17/100
# 8/8 [==============================] - 0s 29ms/step - loss: 14.5741 - accuracy: 0.1605 - val_loss: 13.7423 - val_accuracy: 0.1895
# Epoch 18/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.0783 - accuracy: 0.1820 - val_loss: 14.5038 - val_accuracy: 0.2009
# Epoch 19/100
# 8/8 [==============================] - 0s 32ms/step - loss: 15.0414 - accuracy: 0.1855 - val_loss: 14.7536 - val_accuracy: 0.1985
# Epoch 20/100
# 8/8 [==============================] - 0s 30ms/step - loss: 15.2679 - accuracy: 0.1740 - val_loss: 15.1830 - val_accuracy: 0.1818
# Epoch 21/100
# 8/8 [==============================] - 0s 30ms/step - loss: 15.9121 - accuracy: 0.1745 - val_loss: 15.7927 - val_accuracy: 0.1903
# Epoch 22/100
# 8/8 [==============================] - 0s 29ms/step - loss: 16.1634 - accuracy: 0.1900 - val_loss: 16.0972 - val_accuracy: 0.2118
# Epoch 23/100
# 8/8 [==============================] - 0s 31ms/step - loss: 16.3202 - accuracy: 0.1875 - val_loss: 15.9574 - val_accuracy: 0.2180
# Epoch 24/100
# 8/8 [==============================] - 0s 29ms/step - loss: 16.3554 - accuracy: 0.1865 - val_loss: 15.6193 - val_accuracy: 0.1994
# Epoch 25/100
# 8/8 [==============================] - 0s 29ms/step - loss: 15.9386 - accuracy: 0.1790 - val_loss: 14.9738 - val_accuracy: 0.1931
# Epoch 26/100
# 8/8 [==============================] - 0s 27ms/step - loss: 15.7484 - accuracy: 0.1890 - val_loss: 15.2354 - val_accuracy: 0.1964
# Epoch 27/100
# 8/8 [==============================] - 0s 29ms/step - loss: 16.2794 - accuracy: 0.1840 - val_loss: 15.4832 - val_accuracy: 0.1904
# Epoch 28/100
# 8/8 [==============================] - 0s 28ms/step - loss: 16.0332 - accuracy: 0.1845 - val_loss: 15.6117 - val_accuracy: 0.2017
# Epoch 29/100
# 8/8 [==============================] - 0s 32ms/step - loss: 16.9754 - accuracy: 0.1840 - val_loss: 16.9373 - val_accuracy: 0.2031
# Epoch 30/100
# 8/8 [==============================] - 0s 29ms/step - loss: 18.0342 - accuracy: 0.1825 - val_loss: 17.4504 - val_accuracy: 0.1817
# Epoch 31/100
# 8/8 [==============================] - 0s 30ms/step - loss: 17.8165 - accuracy: 0.1665 - val_loss: 16.8094 - val_accuracy: 0.1813
# Epoch 32/100
# 8/8 [==============================] - 0s 30ms/step - loss: 18.2271 - accuracy: 0.1625 - val_loss: 17.8770 - val_accuracy: 0.1749
# Epoch 33/100
# 8/8 [==============================] - 0s 31ms/step - loss: 18.7043 - accuracy: 0.1560 - val_loss: 18.3198 - val_accuracy: 0.1637
# Epoch 34/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.4819 - accuracy: 0.1440 - val_loss: 18.6437 - val_accuracy: 0.1661
# Epoch 35/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.3784 - accuracy: 0.1580 - val_loss: 19.0894 - val_accuracy: 0.1635
# Epoch 36/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.6913 - accuracy: 0.1590 - val_loss: 18.9481 - val_accuracy: 0.1680
# Epoch 37/100
# 8/8 [==============================] - 0s 34ms/step - loss: 19.8100 - accuracy: 0.1690 - val_loss: 19.2069 - val_accuracy: 0.1739
# Epoch 38/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.5671 - accuracy: 0.1845 - val_loss: 18.9646 - val_accuracy: 0.1780
# Epoch 39/100
# 8/8 [==============================] - 0s 32ms/step - loss: 19.2855 - accuracy: 0.1915 - val_loss: 19.2152 - val_accuracy: 0.1948
# Epoch 40/100
# 8/8 [==============================] - 0s 31ms/step - loss: 19.3079 - accuracy: 0.2100 - val_loss: 18.7449 - val_accuracy: 0.2079
# Epoch 41/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.3887 - accuracy: 0.2105 - val_loss: 19.0323 - val_accuracy: 0.1975
# Epoch 42/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.3281 - accuracy: 0.1995 - val_loss: 18.9202 - val_accuracy: 0.2066
# Epoch 43/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.1072 - accuracy: 0.2175 - val_loss: 18.7290 - val_accuracy: 0.2210
# Epoch 44/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.4686 - accuracy: 0.2295 - val_loss: 18.8213 - val_accuracy: 0.2265
# Epoch 45/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.2620 - accuracy: 0.2395 - val_loss: 18.5122 - val_accuracy: 0.2612
# Epoch 46/100
# 8/8 [==============================] - 0s 28ms/step - loss: 18.4031 - accuracy: 0.2650 - val_loss: 18.1481 - val_accuracy: 0.2571
# Epoch 47/100
# 8/8 [==============================] - 0s 27ms/step - loss: 19.1835 - accuracy: 0.2530 - val_loss: 19.2773 - val_accuracy: 0.2569
# Epoch 48/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.6361 - accuracy: 0.2605 - val_loss: 19.3018 - val_accuracy: 0.2643
# Epoch 49/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.4218 - accuracy: 0.2665 - val_loss: 19.3020 - val_accuracy: 0.2716
# Epoch 50/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.7382 - accuracy: 0.2590 - val_loss: 19.4397 - val_accuracy: 0.2743
# Epoch 51/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.2540 - accuracy: 0.2705 - val_loss: 19.2553 - val_accuracy: 0.2708
# Epoch 52/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.3907 - accuracy: 0.2630 - val_loss: 18.8502 - val_accuracy: 0.2813
# Epoch 53/100
# 8/8 [==============================] - 0s 31ms/step - loss: 19.2940 - accuracy: 0.2645 - val_loss: 18.8177 - val_accuracy: 0.2963
# Epoch 54/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.5131 - accuracy: 0.2750 - val_loss: 18.9924 - val_accuracy: 0.2921
# Epoch 55/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.8848 - accuracy: 0.2685 - val_loss: 19.7829 - val_accuracy: 0.2875
# Epoch 56/100
# 8/8 [==============================] - 0s 31ms/step - loss: 20.2877 - accuracy: 0.2745 - val_loss: 19.2933 - val_accuracy: 0.3012
# Epoch 57/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.7312 - accuracy: 0.2750 - val_loss: 19.0594 - val_accuracy: 0.3002
# Epoch 58/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.6495 - accuracy: 0.2795 - val_loss: 18.9989 - val_accuracy: 0.3067
# Epoch 59/100
# 8/8 [==============================] - 0s 31ms/step - loss: 19.4969 - accuracy: 0.2845 - val_loss: 18.7071 - val_accuracy: 0.3024
# Epoch 60/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.2428 - accuracy: 0.2865 - val_loss: 18.3993 - val_accuracy: 0.3080
# Epoch 61/100
# 8/8 [==============================] - 0s 32ms/step - loss: 19.4911 - accuracy: 0.2855 - val_loss: 19.2622 - val_accuracy: 0.2844
# Epoch 62/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.6247 - accuracy: 0.2715 - val_loss: 19.9322 - val_accuracy: 0.2785
# Epoch 63/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.9617 - accuracy: 0.2655 - val_loss: 20.3826 - val_accuracy: 0.2840
# Epoch 64/100
# 8/8 [==============================] - 0s 31ms/step - loss: 21.2587 - accuracy: 0.2745 - val_loss: 20.3230 - val_accuracy: 0.2789
# Epoch 65/100
# 8/8 [==============================] - 0s 33ms/step - loss: 21.6570 - accuracy: 0.2605 - val_loss: 21.0750 - val_accuracy: 0.2649
# Epoch 66/100
# 8/8 [==============================] - 0s 29ms/step - loss: 22.2221 - accuracy: 0.2525 - val_loss: 22.2169 - val_accuracy: 0.2503
# Epoch 67/100
# 8/8 [==============================] - 0s 27ms/step - loss: 23.0334 - accuracy: 0.2285 - val_loss: 22.0663 - val_accuracy: 0.2414
# Epoch 68/100
# 8/8 [==============================] - 0s 27ms/step - loss: 22.9049 - accuracy: 0.2350 - val_loss: 22.6768 - val_accuracy: 0.2530
# Epoch 69/100
# 8/8 [==============================] - 0s 28ms/step - loss: 23.4812 - accuracy: 0.2285 - val_loss: 23.6787 - val_accuracy: 0.2381
# Epoch 70/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.2325 - accuracy: 0.2310 - val_loss: 24.0944 - val_accuracy: 0.2413
# Epoch 71/100
# 8/8 [==============================] - 0s 28ms/step - loss: 24.4725 - accuracy: 0.2275 - val_loss: 24.5940 - val_accuracy: 0.2330
# Epoch 72/100
# 8/8 [==============================] - 0s 28ms/step - loss: 24.6779 - accuracy: 0.2345 - val_loss: 24.3502 - val_accuracy: 0.2545
# Epoch 73/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.3753 - accuracy: 0.2530 - val_loss: 24.2113 - val_accuracy: 0.2683
# Epoch 74/100
# 8/8 [==============================] - 0s 30ms/step - loss: 24.7353 - accuracy: 0.2525 - val_loss: 24.1482 - val_accuracy: 0.2719
# Epoch 75/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.6419 - accuracy: 0.2630 - val_loss: 24.4786 - val_accuracy: 0.2689
# Epoch 76/100
# 8/8 [==============================] - 0s 29ms/step - loss: 25.5391 - accuracy: 0.2565 - val_loss: 25.0651 - val_accuracy: 0.2715
# Epoch 77/100
# 8/8 [==============================] - 0s 28ms/step - loss: 26.3544 - accuracy: 0.2500 - val_loss: 26.0092 - val_accuracy: 0.2574
# Epoch 78/100
# 8/8 [==============================] - 0s 30ms/step - loss: 26.9356 - accuracy: 0.2455 - val_loss: 26.5806 - val_accuracy: 0.2603
# Epoch 79/100
# 8/8 [==============================] - 0s 31ms/step - loss: 27.0059 - accuracy: 0.2575 - val_loss: 26.2969 - val_accuracy: 0.2603
# Epoch 80/100
# 8/8 [==============================] - 0s 29ms/step - loss: 26.4060 - accuracy: 0.2490 - val_loss: 25.4466 - val_accuracy: 0.2682
# Epoch 81/100
# 8/8 [==============================] - 0s 29ms/step - loss: 26.1380 - accuracy: 0.2560 - val_loss: 25.8716 - val_accuracy: 0.2540
# Epoch 82/100
# 8/8 [==============================] - 0s 32ms/step - loss: 26.5647 - accuracy: 0.2415 - val_loss: 25.7069 - val_accuracy: 0.2529
# Epoch 83/100
# 8/8 [==============================] - 0s 29ms/step - loss: 26.4182 - accuracy: 0.2405 - val_loss: 25.1082 - val_accuracy: 0.2583
# Epoch 84/100
# 8/8 [==============================] - 0s 30ms/step - loss: 25.7072 - accuracy: 0.2545 - val_loss: 25.1614 - val_accuracy: 0.2535
# Epoch 85/100
# 8/8 [==============================] - 0s 29ms/step - loss: 26.2481 - accuracy: 0.2335 - val_loss: 25.7873 - val_accuracy: 0.2431
# Epoch 86/100
# 8/8 [==============================] - 0s 29ms/step - loss: 27.0381 - accuracy: 0.2195 - val_loss: 26.3359 - val_accuracy: 0.2352
# Epoch 87/100
# 8/8 [==============================] - 0s 28ms/step - loss: 27.0297 - accuracy: 0.2220 - val_loss: 26.4824 - val_accuracy: 0.2349
# Epoch 88/100
# 8/8 [==============================] - 0s 31ms/step - loss: 27.2870 - accuracy: 0.2200 - val_loss: 26.4772 - val_accuracy: 0.2264
# Epoch 89/100
# 8/8 [==============================] - 0s 27ms/step - loss: 27.2611 - accuracy: 0.2065 - val_loss: 26.3457 - val_accuracy: 0.2203
# Epoch 90/100
# 8/8 [==============================] - 0s 28ms/step - loss: 26.6990 - accuracy: 0.2060 - val_loss: 26.2855 - val_accuracy: 0.2245
# Epoch 91/100
# 8/8 [==============================] - 0s 32ms/step - loss: 27.6780 - accuracy: 0.2010 - val_loss: 27.4485 - val_accuracy: 0.2059
# Epoch 92/100
# 8/8 [==============================] - 0s 30ms/step - loss: 27.8854 - accuracy: 0.1945 - val_loss: 27.1903 - val_accuracy: 0.2142
# Epoch 93/100
# 8/8 [==============================] - 0s 32ms/step - loss: 27.9330 - accuracy: 0.1960 - val_loss: 26.5955 - val_accuracy: 0.2152
# Epoch 94/100
# 8/8 [==============================] - 0s 30ms/step - loss: 27.3535 - accuracy: 0.1990 - val_loss: 26.5185 - val_accuracy: 0.2220
# Epoch 95/100
# 8/8 [==============================] - 0s 30ms/step - loss: 27.6847 - accuracy: 0.2090 - val_loss: 26.8605 - val_accuracy: 0.2247
# Epoch 96/100
# 8/8 [==============================] - 0s 29ms/step - loss: 27.9886 - accuracy: 0.1975 - val_loss: 27.5816 - val_accuracy: 0.2032
# Epoch 97/100
# 8/8 [==============================] - 0s 28ms/step - loss: 28.6229 - accuracy: 0.1845 - val_loss: 27.8743 - val_accuracy: 0.2019
# Epoch 98/100
# 8/8 [==============================] - 0s 29ms/step - loss: 28.5857 - accuracy: 0.2040 - val_loss: 27.5409 - val_accuracy: 0.2142
# Epoch 99/100
# 8/8 [==============================] - 0s 29ms/step - loss: 28.7077 - accuracy: 0.2145 - val_loss: 28.6219 - val_accuracy: 0.2197
# Epoch 100/100
# 8/8 [==============================] - 0s 30ms/step - loss: 29.6526 - accuracy: 0.2260 - val_loss: 29.3916 - val_accuracy: 0.2320
# Performing experiment for epsilon = 0.01
# Epoch 1/100
# 8/8 [==============================] - 1s 43ms/step - loss: 4.1054 - accuracy: 0.0985 - val_loss: 4.8590 - val_accuracy: 0.1136
# Epoch 2/100
# 8/8 [==============================] - 0s 32ms/step - loss: 6.4505 - accuracy: 0.1220 - val_loss: 6.1770 - val_accuracy: 0.1730
# Epoch 3/100
# 8/8 [==============================] - 0s 30ms/step - loss: 7.0901 - accuracy: 0.1250 - val_loss: 7.1962 - val_accuracy: 0.1624
# Epoch 4/100
# 8/8 [==============================] - 0s 28ms/step - loss: 7.8045 - accuracy: 0.1500 - val_loss: 7.4027 - val_accuracy: 0.1559
# Epoch 5/100
# 8/8 [==============================] - 0s 30ms/step - loss: 8.1073 - accuracy: 0.1330 - val_loss: 8.8664 - val_accuracy: 0.1438
# Epoch 6/100
# 8/8 [==============================] - 0s 30ms/step - loss: 9.7114 - accuracy: 0.1565 - val_loss: 10.5331 - val_accuracy: 0.1428
# Epoch 7/100
# 8/8 [==============================] - 0s 27ms/step - loss: 10.5664 - accuracy: 0.1220 - val_loss: 10.5408 - val_accuracy: 0.1405
# Epoch 8/100
# 8/8 [==============================] - 0s 28ms/step - loss: 10.9170 - accuracy: 0.1315 - val_loss: 11.5717 - val_accuracy: 0.1401
# Epoch 9/100
# 8/8 [==============================] - 0s 31ms/step - loss: 11.7534 - accuracy: 0.1310 - val_loss: 12.5083 - val_accuracy: 0.1359
# Epoch 10/100
# 8/8 [==============================] - 0s 30ms/step - loss: 12.7908 - accuracy: 0.1120 - val_loss: 13.5184 - val_accuracy: 0.1137
# Epoch 11/100
# 8/8 [==============================] - 0s 29ms/step - loss: 13.4432 - accuracy: 0.1075 - val_loss: 14.4606 - val_accuracy: 0.0913
# Epoch 12/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.5136 - accuracy: 0.0925 - val_loss: 15.3859 - val_accuracy: 0.1015
# Epoch 13/100
# 8/8 [==============================] - 0s 31ms/step - loss: 15.1399 - accuracy: 0.0905 - val_loss: 15.4310 - val_accuracy: 0.0838
# Epoch 14/100
# 8/8 [==============================] - 0s 32ms/step - loss: 15.1572 - accuracy: 0.0765 - val_loss: 15.7331 - val_accuracy: 0.0841
# Epoch 15/100
# 8/8 [==============================] - 0s 29ms/step - loss: 15.6088 - accuracy: 0.0695 - val_loss: 16.2115 - val_accuracy: 0.0796
# Epoch 16/100
# 8/8 [==============================] - 0s 30ms/step - loss: 16.4646 - accuracy: 0.0755 - val_loss: 16.9143 - val_accuracy: 0.0751
# Epoch 17/100
# 8/8 [==============================] - 0s 31ms/step - loss: 16.5084 - accuracy: 0.0700 - val_loss: 16.3683 - val_accuracy: 0.0742
# Epoch 18/100
# 8/8 [==============================] - 0s 29ms/step - loss: 15.8784 - accuracy: 0.0855 - val_loss: 16.7349 - val_accuracy: 0.0874
# Epoch 19/100
# 8/8 [==============================] - 0s 31ms/step - loss: 16.6061 - accuracy: 0.0900 - val_loss: 16.7834 - val_accuracy: 0.0960
# Epoch 20/100
# 8/8 [==============================] - 0s 30ms/step - loss: 16.6231 - accuracy: 0.0920 - val_loss: 16.9440 - val_accuracy: 0.1059
# Epoch 21/100
# 8/8 [==============================] - 0s 31ms/step - loss: 16.8518 - accuracy: 0.1105 - val_loss: 17.2712 - val_accuracy: 0.1135
# Epoch 22/100
# 8/8 [==============================] - 0s 29ms/step - loss: 16.9707 - accuracy: 0.1180 - val_loss: 17.2136 - val_accuracy: 0.1187
# Epoch 23/100
# 8/8 [==============================] - 0s 30ms/step - loss: 17.1218 - accuracy: 0.1160 - val_loss: 17.6459 - val_accuracy: 0.1196
# Epoch 24/100
# 8/8 [==============================] - 0s 28ms/step - loss: 18.1670 - accuracy: 0.1110 - val_loss: 18.6832 - val_accuracy: 0.1191
# Epoch 25/100
# 8/8 [==============================] - 0s 30ms/step - loss: 18.7251 - accuracy: 0.1185 - val_loss: 19.7963 - val_accuracy: 0.1260
# Epoch 26/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.4573 - accuracy: 0.1390 - val_loss: 20.2145 - val_accuracy: 0.1434
# Epoch 27/100
# 8/8 [==============================] - 0s 34ms/step - loss: 20.2497 - accuracy: 0.1445 - val_loss: 20.6239 - val_accuracy: 0.1438
# Epoch 28/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.9532 - accuracy: 0.1310 - val_loss: 20.2718 - val_accuracy: 0.1328
# Epoch 29/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.2494 - accuracy: 0.1220 - val_loss: 19.6886 - val_accuracy: 0.1235
# Epoch 30/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.7639 - accuracy: 0.1295 - val_loss: 19.3849 - val_accuracy: 0.1368
# Epoch 31/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.7433 - accuracy: 0.1205 - val_loss: 19.6068 - val_accuracy: 0.1271
# Epoch 32/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.8038 - accuracy: 0.1220 - val_loss: 20.4704 - val_accuracy: 0.1175
# Epoch 33/100
# 8/8 [==============================] - 0s 30ms/step - loss: 21.0970 - accuracy: 0.1235 - val_loss: 21.3220 - val_accuracy: 0.1306
# Epoch 34/100
# 8/8 [==============================] - 0s 32ms/step - loss: 21.2366 - accuracy: 0.1295 - val_loss: 20.7038 - val_accuracy: 0.1446
# Epoch 35/100
# 8/8 [==============================] - 0s 30ms/step - loss: 21.0331 - accuracy: 0.1325 - val_loss: 20.9200 - val_accuracy: 0.1528
# Epoch 36/100
# 8/8 [==============================] - 0s 30ms/step - loss: 21.3435 - accuracy: 0.1425 - val_loss: 20.6430 - val_accuracy: 0.1495
# Epoch 37/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.9193 - accuracy: 0.1500 - val_loss: 20.2367 - val_accuracy: 0.1591
# Epoch 38/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.9444 - accuracy: 0.1600 - val_loss: 20.8348 - val_accuracy: 0.1627
# Epoch 39/100
# 8/8 [==============================] - 0s 29ms/step - loss: 21.0237 - accuracy: 0.1630 - val_loss: 20.5198 - val_accuracy: 0.1798
# Epoch 40/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.7985 - accuracy: 0.1740 - val_loss: 20.4081 - val_accuracy: 0.1778
# Epoch 41/100
# 8/8 [==============================] - 0s 31ms/step - loss: 20.3403 - accuracy: 0.1825 - val_loss: 19.7585 - val_accuracy: 0.1825
# Epoch 42/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.3077 - accuracy: 0.1790 - val_loss: 20.2406 - val_accuracy: 0.1817
# Epoch 43/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.1935 - accuracy: 0.1815 - val_loss: 19.6610 - val_accuracy: 0.1852
# Epoch 44/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.8283 - accuracy: 0.1885 - val_loss: 19.7860 - val_accuracy: 0.1898
# Epoch 45/100
# 8/8 [==============================] - 0s 32ms/step - loss: 19.8810 - accuracy: 0.1860 - val_loss: 19.9169 - val_accuracy: 0.1851
# Epoch 46/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.9839 - accuracy: 0.1920 - val_loss: 19.9495 - val_accuracy: 0.1935
# Epoch 47/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.4741 - accuracy: 0.2055 - val_loss: 19.9167 - val_accuracy: 0.2104
# Epoch 48/100
# 8/8 [==============================] - 0s 28ms/step - loss: 19.1682 - accuracy: 0.2195 - val_loss: 18.9993 - val_accuracy: 0.2334
# Epoch 49/100
# 8/8 [==============================] - 0s 29ms/step - loss: 18.9481 - accuracy: 0.2360 - val_loss: 19.4519 - val_accuracy: 0.2344
# Epoch 50/100
# 8/8 [==============================] - 0s 27ms/step - loss: 19.4534 - accuracy: 0.2310 - val_loss: 19.5783 - val_accuracy: 0.2360
# Epoch 51/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.1799 - accuracy: 0.2255 - val_loss: 19.3516 - val_accuracy: 0.2308
# Epoch 52/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.0752 - accuracy: 0.2230 - val_loss: 19.2333 - val_accuracy: 0.2353
# Epoch 53/100
# 8/8 [==============================] - 0s 30ms/step - loss: 19.1021 - accuracy: 0.2395 - val_loss: 19.6172 - val_accuracy: 0.2382
# Epoch 54/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.5905 - accuracy: 0.2295 - val_loss: 19.8442 - val_accuracy: 0.2297
# Epoch 55/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.0043 - accuracy: 0.2285 - val_loss: 20.7778 - val_accuracy: 0.2309
# Epoch 56/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.8207 - accuracy: 0.2260 - val_loss: 20.7238 - val_accuracy: 0.2325
# Epoch 57/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.7833 - accuracy: 0.2290 - val_loss: 20.4037 - val_accuracy: 0.2384
# Epoch 58/100
# 8/8 [==============================] - 0s 31ms/step - loss: 19.9325 - accuracy: 0.2395 - val_loss: 20.1851 - val_accuracy: 0.2330
# Epoch 59/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.3261 - accuracy: 0.2285 - val_loss: 20.3936 - val_accuracy: 0.2338
# Epoch 60/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.3843 - accuracy: 0.2280 - val_loss: 20.5094 - val_accuracy: 0.2236
# Epoch 61/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.5244 - accuracy: 0.2220 - val_loss: 20.7084 - val_accuracy: 0.2219
# Epoch 62/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.5091 - accuracy: 0.2305 - val_loss: 20.7780 - val_accuracy: 0.2239
# Epoch 63/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.5387 - accuracy: 0.2235 - val_loss: 19.6741 - val_accuracy: 0.2385
# Epoch 64/100
# 8/8 [==============================] - 0s 32ms/step - loss: 19.9228 - accuracy: 0.2315 - val_loss: 19.5733 - val_accuracy: 0.2310
# Epoch 65/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.3560 - accuracy: 0.2330 - val_loss: 20.5046 - val_accuracy: 0.2180
# Epoch 66/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.8177 - accuracy: 0.2395 - val_loss: 20.3724 - val_accuracy: 0.2426
# Epoch 67/100
# 8/8 [==============================] - 0s 29ms/step - loss: 21.1399 - accuracy: 0.2355 - val_loss: 20.1437 - val_accuracy: 0.2391
# Epoch 68/100
# 8/8 [==============================] - 0s 34ms/step - loss: 20.6677 - accuracy: 0.2425 - val_loss: 19.6863 - val_accuracy: 0.2483
# Epoch 69/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.4455 - accuracy: 0.2440 - val_loss: 20.5921 - val_accuracy: 0.2437
# Epoch 70/100
# 8/8 [==============================] - 0s 31ms/step - loss: 20.9555 - accuracy: 0.2500 - val_loss: 21.2578 - val_accuracy: 0.2512
# Epoch 71/100
# 8/8 [==============================] - 0s 30ms/step - loss: 21.6576 - accuracy: 0.2400 - val_loss: 21.3206 - val_accuracy: 0.2468
# Epoch 72/100
# 8/8 [==============================] - 0s 30ms/step - loss: 21.2806 - accuracy: 0.2435 - val_loss: 21.4414 - val_accuracy: 0.2426
# Epoch 73/100
# 8/8 [==============================] - 0s 32ms/step - loss: 21.1750 - accuracy: 0.2395 - val_loss: 20.6938 - val_accuracy: 0.2548
# Epoch 74/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.9301 - accuracy: 0.2395 - val_loss: 21.1402 - val_accuracy: 0.2443
# Epoch 75/100
# 8/8 [==============================] - 0s 29ms/step - loss: 21.4898 - accuracy: 0.2370 - val_loss: 21.4837 - val_accuracy: 0.2393
# Epoch 76/100
# 8/8 [==============================] - 0s 30ms/step - loss: 21.0688 - accuracy: 0.2375 - val_loss: 20.7064 - val_accuracy: 0.2497
# Epoch 77/100
# 8/8 [==============================] - 0s 32ms/step - loss: 20.8243 - accuracy: 0.2470 - val_loss: 20.7146 - val_accuracy: 0.2481
# Epoch 78/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.5373 - accuracy: 0.2450 - val_loss: 20.3398 - val_accuracy: 0.2439
# Epoch 79/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.2770 - accuracy: 0.2400 - val_loss: 20.0415 - val_accuracy: 0.2419
# Epoch 80/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.0252 - accuracy: 0.2395 - val_loss: 19.7675 - val_accuracy: 0.2436
# Epoch 81/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.1993 - accuracy: 0.2400 - val_loss: 20.2569 - val_accuracy: 0.2427
# Epoch 82/100
# 8/8 [==============================] - 0s 31ms/step - loss: 20.2463 - accuracy: 0.2430 - val_loss: 20.7069 - val_accuracy: 0.2450
# Epoch 83/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.4375 - accuracy: 0.2380 - val_loss: 20.9230 - val_accuracy: 0.2307
# Epoch 84/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.6528 - accuracy: 0.2270 - val_loss: 20.8271 - val_accuracy: 0.2428
# Epoch 85/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.6827 - accuracy: 0.2295 - val_loss: 20.5793 - val_accuracy: 0.2433
# Epoch 86/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.6873 - accuracy: 0.2205 - val_loss: 20.4917 - val_accuracy: 0.2379
# Epoch 87/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.8260 - accuracy: 0.2195 - val_loss: 21.5527 - val_accuracy: 0.2154
# Epoch 88/100
# 8/8 [==============================] - 0s 31ms/step - loss: 21.9264 - accuracy: 0.2040 - val_loss: 22.7405 - val_accuracy: 0.2074
# Epoch 89/100
# 8/8 [==============================] - 0s 28ms/step - loss: 22.8138 - accuracy: 0.1905 - val_loss: 22.6823 - val_accuracy: 0.2093
# Epoch 90/100
# 8/8 [==============================] - 0s 30ms/step - loss: 22.5937 - accuracy: 0.2025 - val_loss: 22.8115 - val_accuracy: 0.2152
# Epoch 91/100
# 8/8 [==============================] - 0s 31ms/step - loss: 22.7442 - accuracy: 0.2105 - val_loss: 22.8265 - val_accuracy: 0.2276
# Epoch 92/100
# 8/8 [==============================] - 0s 30ms/step - loss: 22.9389 - accuracy: 0.2135 - val_loss: 23.0246 - val_accuracy: 0.2319
# Epoch 93/100
# 8/8 [==============================] - 0s 29ms/step - loss: 23.0267 - accuracy: 0.2215 - val_loss: 23.0772 - val_accuracy: 0.2456
# Epoch 94/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.0262 - accuracy: 0.2400 - val_loss: 23.5266 - val_accuracy: 0.2529
# Epoch 95/100
# 8/8 [==============================] - 0s 27ms/step - loss: 23.4456 - accuracy: 0.2350 - val_loss: 24.1048 - val_accuracy: 0.2455
# Epoch 96/100
# 8/8 [==============================] - 0s 28ms/step - loss: 24.2772 - accuracy: 0.2345 - val_loss: 25.5526 - val_accuracy: 0.2366
# Epoch 97/100
# 8/8 [==============================] - 0s 27ms/step - loss: 24.8922 - accuracy: 0.2405 - val_loss: 24.3365 - val_accuracy: 0.2502
# Epoch 98/100
# 8/8 [==============================] - 0s 29ms/step - loss: 24.2102 - accuracy: 0.2425 - val_loss: 24.3354 - val_accuracy: 0.2437
# Epoch 99/100
# 8/8 [==============================] - 0s 30ms/step - loss: 23.8470 - accuracy: 0.2420 - val_loss: 24.3812 - val_accuracy: 0.2365
# Epoch 100/100
# 8/8 [==============================] - 0s 29ms/step - loss: 23.9735 - accuracy: 0.2430 - val_loss: 24.2659 - val_accuracy: 0.2486
# Performing experiment for epsilon = 0.01
# Epoch 1/100
# 8/8 [==============================] - 1s 42ms/step - loss: 3.8346 - accuracy: 0.0930 - val_loss: 5.1708 - val_accuracy: 0.0974
# Epoch 2/100
# 8/8 [==============================] - 0s 30ms/step - loss: 5.6648 - accuracy: 0.1015 - val_loss: 5.5194 - val_accuracy: 0.1357
# Epoch 3/100
# 8/8 [==============================] - 0s 28ms/step - loss: 6.1299 - accuracy: 0.1430 - val_loss: 6.6699 - val_accuracy: 0.1554
# Epoch 4/100
# 8/8 [==============================] - 0s 28ms/step - loss: 7.1491 - accuracy: 0.1335 - val_loss: 7.3466 - val_accuracy: 0.1325
# Epoch 5/100
# 8/8 [==============================] - 0s 31ms/step - loss: 8.0054 - accuracy: 0.1175 - val_loss: 8.0482 - val_accuracy: 0.1427
# Epoch 6/100
# 8/8 [==============================] - 0s 30ms/step - loss: 8.6404 - accuracy: 0.1435 - val_loss: 9.2420 - val_accuracy: 0.1621
# Epoch 7/100
# 8/8 [==============================] - 0s 31ms/step - loss: 9.8685 - accuracy: 0.1410 - val_loss: 10.4689 - val_accuracy: 0.1450
# Epoch 8/100
# 8/8 [==============================] - 0s 30ms/step - loss: 11.0624 - accuracy: 0.1465 - val_loss: 11.0949 - val_accuracy: 0.1365
# Epoch 9/100
# 8/8 [==============================] - 0s 29ms/step - loss: 11.1069 - accuracy: 0.1435 - val_loss: 10.7947 - val_accuracy: 0.1375
# Epoch 10/100
# 8/8 [==============================] - 0s 30ms/step - loss: 10.9443 - accuracy: 0.1690 - val_loss: 10.9769 - val_accuracy: 0.1681
# Epoch 11/100
# 8/8 [==============================] - 0s 29ms/step - loss: 11.6155 - accuracy: 0.1780 - val_loss: 12.1974 - val_accuracy: 0.1823
# Epoch 12/100
# 8/8 [==============================] - 0s 29ms/step - loss: 12.6663 - accuracy: 0.1760 - val_loss: 12.8971 - val_accuracy: 0.1536
# Epoch 13/100
# 8/8 [==============================] - 0s 30ms/step - loss: 13.8618 - accuracy: 0.1490 - val_loss: 13.8771 - val_accuracy: 0.1474
# Epoch 14/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.5306 - accuracy: 0.1515 - val_loss: 14.7536 - val_accuracy: 0.1567
# Epoch 15/100
# 8/8 [==============================] - 0s 30ms/step - loss: 15.1711 - accuracy: 0.1465 - val_loss: 14.8276 - val_accuracy: 0.1812
# Epoch 16/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.8641 - accuracy: 0.1840 - val_loss: 13.8811 - val_accuracy: 0.2093
# Epoch 17/100
# 8/8 [==============================] - 0s 29ms/step - loss: 14.4728 - accuracy: 0.2015 - val_loss: 14.1838 - val_accuracy: 0.2060
# Epoch 18/100
# 8/8 [==============================] - 0s 31ms/step - loss: 14.4192 - accuracy: 0.2075 - val_loss: 13.9263 - val_accuracy: 0.2042
# Epoch 19/100
# 8/8 [==============================] - 0s 27ms/step - loss: 14.3778 - accuracy: 0.1810 - val_loss: 13.9054 - val_accuracy: 0.2089
# Epoch 20/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.3144 - accuracy: 0.2085 - val_loss: 13.6327 - val_accuracy: 0.2098
# Epoch 21/100
# 8/8 [==============================] - 0s 32ms/step - loss: 14.2838 - accuracy: 0.2090 - val_loss: 13.5063 - val_accuracy: 0.2128
# Epoch 22/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.5163 - accuracy: 0.2015 - val_loss: 14.3484 - val_accuracy: 0.2030
# Epoch 23/100
# 8/8 [==============================] - 0s 32ms/step - loss: 14.9028 - accuracy: 0.2015 - val_loss: 14.7287 - val_accuracy: 0.2207
# Epoch 24/100
# 8/8 [==============================] - 0s 30ms/step - loss: 15.0887 - accuracy: 0.2145 - val_loss: 14.4114 - val_accuracy: 0.2260
# Epoch 25/100
# 8/8 [==============================] - 0s 28ms/step - loss: 14.6254 - accuracy: 0.2190 - val_loss: 13.6724 - val_accuracy: 0.2421
# Epoch 26/100
# 8/8 [==============================] - 0s 30ms/step - loss: 14.2375 - accuracy: 0.2445 - val_loss: 13.5825 - val_accuracy: 0.2519
# Epoch 27/100
# 8/8 [==============================] - 0s 27ms/step - loss: 14.3567 - accuracy: 0.2285 - val_loss: 13.3351 - val_accuracy: 0.2595
# Epoch 28/100
# 8/8 [==============================] - 0s 29ms/step - loss: 14.4692 - accuracy: 0.2390 - val_loss: 14.2120 - val_accuracy: 0.2504
# Epoch 29/100
# 8/8 [==============================] - 0s 31ms/step - loss: 14.8910 - accuracy: 0.2355 - val_loss: 15.1736 - val_accuracy: 0.2297
# Epoch 30/100
# 8/8 [==============================] - 0s 28ms/step - loss: 15.6595 - accuracy: 0.2365 - val_loss: 16.1481 - val_accuracy: 0.2506
# Epoch 31/100
# 8/8 [==============================] - 0s 30ms/step - loss: 16.3291 - accuracy: 0.2435 - val_loss: 16.0498 - val_accuracy: 0.2594
# Epoch 32/100
# 8/8 [==============================] - 0s 30ms/step - loss: 15.5432 - accuracy: 0.2595 - val_loss: 14.8430 - val_accuracy: 0.2842
# Epoch 33/100
# 8/8 [==============================] - 0s 28ms/step - loss: 15.2452 - accuracy: 0.2735 - val_loss: 15.1024 - val_accuracy: 0.2860
# Epoch 34/100
# 8/8 [==============================] - 0s 27ms/step - loss: 15.8694 - accuracy: 0.2645 - val_loss: 15.4753 - val_accuracy: 0.2813
# Epoch 35/100
# 8/8 [==============================] - 0s 28ms/step - loss: 15.1826 - accuracy: 0.2755 - val_loss: 15.1948 - val_accuracy: 0.2850
# Epoch 36/100
# ...
# Epoch 88/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3647 - accuracy: 0.8960 - val_loss: 0.4021 - val_accuracy: 0.8788
# Epoch 89/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3633 - accuracy: 0.8985 - val_loss: 0.4016 - val_accuracy: 0.8785
# Epoch 90/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3627 - accuracy: 0.8960 - val_loss: 0.4007 - val_accuracy: 0.8793
# Epoch 91/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3618 - accuracy: 0.8970 - val_loss: 0.4004 - val_accuracy: 0.8798
# Epoch 92/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3606 - accuracy: 0.8965 - val_loss: 0.4000 - val_accuracy: 0.8792
# Epoch 93/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3600 - accuracy: 0.8985 - val_loss: 0.3992 - val_accuracy: 0.8804
# Epoch 94/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3588 - accuracy: 0.8975 - val_loss: 0.3987 - val_accuracy: 0.8808
# Epoch 95/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3577 - accuracy: 0.8975 - val_loss: 0.3988 - val_accuracy: 0.8802
# Epoch 96/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3569 - accuracy: 0.8995 - val_loss: 0.3986 - val_accuracy: 0.8803
# Epoch 97/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3559 - accuracy: 0.9000 - val_loss: 0.3978 - val_accuracy: 0.8807
# Epoch 98/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3554 - accuracy: 0.8990 - val_loss: 0.3973 - val_accuracy: 0.8807
# Epoch 99/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3541 - accuracy: 0.9010 - val_loss: 0.3972 - val_accuracy: 0.8813
# Epoch 100/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3532 - accuracy: 0.8985 - val_loss: 0.3966 - val_accuracy: 0.8814
# Performing experiment for epsilon = 50
# Epoch 1/100
# 8/8 [==============================] - 1s 50ms/step - loss: 2.3074 - accuracy: 0.1840 - val_loss: 2.0847 - val_accuracy: 0.3111
# Epoch 2/100
# 8/8 [==============================] - 0s 36ms/step - loss: 1.9685 - accuracy: 0.3735 - val_loss: 1.8026 - val_accuracy: 0.4732
# Epoch 3/100
# 8/8 [==============================] - 0s 33ms/step - loss: 1.7131 - accuracy: 0.5330 - val_loss: 1.5759 - val_accuracy: 0.5818
# Epoch 4/100
# 8/8 [==============================] - 0s 33ms/step - loss: 1.5086 - accuracy: 0.6080 - val_loss: 1.3936 - val_accuracy: 0.6506
# Epoch 5/100
# 8/8 [==============================] - 0s 32ms/step - loss: 1.3464 - accuracy: 0.6540 - val_loss: 1.2483 - val_accuracy: 0.6933
# Epoch 6/100
# 8/8 [==============================] - 0s 34ms/step - loss: 1.2131 - accuracy: 0.6925 - val_loss: 1.1268 - val_accuracy: 0.7249
# Epoch 7/100
# 8/8 [==============================] - 0s 35ms/step - loss: 1.1015 - accuracy: 0.7250 - val_loss: 1.0321 - val_accuracy: 0.7431
# Epoch 8/100
# 8/8 [==============================] - 0s 36ms/step - loss: 1.0169 - accuracy: 0.7390 - val_loss: 0.9520 - val_accuracy: 0.7598
# Epoch 9/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.9410 - accuracy: 0.7550 - val_loss: 0.8878 - val_accuracy: 0.7699
# Epoch 10/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8838 - accuracy: 0.7615 - val_loss: 0.8319 - val_accuracy: 0.7819
# Epoch 11/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.8295 - accuracy: 0.7755 - val_loss: 0.7873 - val_accuracy: 0.7884
# Epoch 12/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.7883 - accuracy: 0.7835 - val_loss: 0.7487 - val_accuracy: 0.7949
# Epoch 13/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7525 - accuracy: 0.7930 - val_loss: 0.7161 - val_accuracy: 0.8019
# Epoch 14/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7224 - accuracy: 0.7980 - val_loss: 0.6867 - val_accuracy: 0.8080
# Epoch 15/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6909 - accuracy: 0.8085 - val_loss: 0.6639 - val_accuracy: 0.8117
# Epoch 16/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6687 - accuracy: 0.8130 - val_loss: 0.6428 - val_accuracy: 0.8153
# Epoch 17/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6477 - accuracy: 0.8195 - val_loss: 0.6238 - val_accuracy: 0.8190
# Epoch 18/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6277 - accuracy: 0.8280 - val_loss: 0.6079 - val_accuracy: 0.8224
# Epoch 19/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6115 - accuracy: 0.8300 - val_loss: 0.5941 - val_accuracy: 0.8246
# Epoch 20/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5952 - accuracy: 0.8345 - val_loss: 0.5811 - val_accuracy: 0.8280
# Epoch 21/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5830 - accuracy: 0.8350 - val_loss: 0.5693 - val_accuracy: 0.8309
# Epoch 22/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5707 - accuracy: 0.8415 - val_loss: 0.5595 - val_accuracy: 0.8322
# Epoch 23/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5597 - accuracy: 0.8420 - val_loss: 0.5504 - val_accuracy: 0.8355
# Epoch 24/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5494 - accuracy: 0.8475 - val_loss: 0.5420 - val_accuracy: 0.8368
# Epoch 25/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5417 - accuracy: 0.8470 - val_loss: 0.5338 - val_accuracy: 0.8392
# Epoch 26/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5314 - accuracy: 0.8535 - val_loss: 0.5269 - val_accuracy: 0.8398
# Epoch 27/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5250 - accuracy: 0.8530 - val_loss: 0.5196 - val_accuracy: 0.8419
# Epoch 28/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5176 - accuracy: 0.8545 - val_loss: 0.5135 - val_accuracy: 0.8430
# Epoch 29/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5103 - accuracy: 0.8575 - val_loss: 0.5077 - val_accuracy: 0.8447
# Epoch 30/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5042 - accuracy: 0.8580 - val_loss: 0.5027 - val_accuracy: 0.8469
# Epoch 31/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4980 - accuracy: 0.8585 - val_loss: 0.4974 - val_accuracy: 0.8484
# Epoch 32/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4932 - accuracy: 0.8600 - val_loss: 0.4924 - val_accuracy: 0.8497
# Epoch 33/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4878 - accuracy: 0.8615 - val_loss: 0.4884 - val_accuracy: 0.8506
# Epoch 34/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4821 - accuracy: 0.8615 - val_loss: 0.4846 - val_accuracy: 0.8509
# Epoch 35/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4779 - accuracy: 0.8670 - val_loss: 0.4809 - val_accuracy: 0.8513
# Epoch 36/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4737 - accuracy: 0.8665 - val_loss: 0.4773 - val_accuracy: 0.8519
# Epoch 37/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4692 - accuracy: 0.8650 - val_loss: 0.4731 - val_accuracy: 0.8546
# Epoch 38/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4644 - accuracy: 0.8685 - val_loss: 0.4695 - val_accuracy: 0.8567
# Epoch 39/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4602 - accuracy: 0.8710 - val_loss: 0.4665 - val_accuracy: 0.8571
# Epoch 40/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4570 - accuracy: 0.8695 - val_loss: 0.4638 - val_accuracy: 0.8573
# Epoch 41/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4536 - accuracy: 0.8710 - val_loss: 0.4611 - val_accuracy: 0.8587
# Epoch 42/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4503 - accuracy: 0.8715 - val_loss: 0.4586 - val_accuracy: 0.8588
# Epoch 43/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4471 - accuracy: 0.8730 - val_loss: 0.4563 - val_accuracy: 0.8591
# Epoch 44/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4443 - accuracy: 0.8715 - val_loss: 0.4532 - val_accuracy: 0.8607
# Epoch 45/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4402 - accuracy: 0.8715 - val_loss: 0.4503 - val_accuracy: 0.8616
# Epoch 46/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4375 - accuracy: 0.8745 - val_loss: 0.4484 - val_accuracy: 0.8619
# Epoch 47/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4348 - accuracy: 0.8730 - val_loss: 0.4463 - val_accuracy: 0.8623
# Epoch 48/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4322 - accuracy: 0.8740 - val_loss: 0.4442 - val_accuracy: 0.8633
# Epoch 49/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4299 - accuracy: 0.8755 - val_loss: 0.4424 - val_accuracy: 0.8639
# Epoch 50/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4274 - accuracy: 0.8760 - val_loss: 0.4405 - val_accuracy: 0.8646
# Epoch 51/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4252 - accuracy: 0.8760 - val_loss: 0.4385 - val_accuracy: 0.8656
# Epoch 52/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4222 - accuracy: 0.8750 - val_loss: 0.4374 - val_accuracy: 0.8656
# Epoch 53/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4207 - accuracy: 0.8770 - val_loss: 0.4354 - val_accuracy: 0.8658
# Epoch 54/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4181 - accuracy: 0.8780 - val_loss: 0.4341 - val_accuracy: 0.8661
# Epoch 55/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4159 - accuracy: 0.8785 - val_loss: 0.4327 - val_accuracy: 0.8671
# Epoch 56/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4142 - accuracy: 0.8800 - val_loss: 0.4313 - val_accuracy: 0.8678
# Epoch 57/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4117 - accuracy: 0.8790 - val_loss: 0.4302 - val_accuracy: 0.8683
# Epoch 58/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4103 - accuracy: 0.8800 - val_loss: 0.4289 - val_accuracy: 0.8684
# Epoch 59/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4086 - accuracy: 0.8795 - val_loss: 0.4278 - val_accuracy: 0.8688
# Epoch 60/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4070 - accuracy: 0.8810 - val_loss: 0.4259 - val_accuracy: 0.8692
# Epoch 61/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4045 - accuracy: 0.8830 - val_loss: 0.4251 - val_accuracy: 0.8692
# Epoch 62/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4036 - accuracy: 0.8855 - val_loss: 0.4234 - val_accuracy: 0.8698
# Epoch 63/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4012 - accuracy: 0.8850 - val_loss: 0.4229 - val_accuracy: 0.8704
# Epoch 64/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3998 - accuracy: 0.8855 - val_loss: 0.4214 - val_accuracy: 0.8711
# Epoch 65/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3978 - accuracy: 0.8875 - val_loss: 0.4202 - val_accuracy: 0.8711
# Epoch 66/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3964 - accuracy: 0.8875 - val_loss: 0.4194 - val_accuracy: 0.8719
# Epoch 67/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3954 - accuracy: 0.8885 - val_loss: 0.4185 - val_accuracy: 0.8719
# Epoch 68/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3943 - accuracy: 0.8890 - val_loss: 0.4176 - val_accuracy: 0.8723
# Epoch 69/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3917 - accuracy: 0.8890 - val_loss: 0.4170 - val_accuracy: 0.8727
# Epoch 70/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3910 - accuracy: 0.8895 - val_loss: 0.4158 - val_accuracy: 0.8735
# Epoch 71/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3894 - accuracy: 0.8900 - val_loss: 0.4148 - val_accuracy: 0.8738
# Epoch 72/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3877 - accuracy: 0.8915 - val_loss: 0.4138 - val_accuracy: 0.8737
# Epoch 73/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3872 - accuracy: 0.8920 - val_loss: 0.4126 - val_accuracy: 0.8748
# Epoch 74/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3850 - accuracy: 0.8910 - val_loss: 0.4124 - val_accuracy: 0.8745
# Epoch 75/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3843 - accuracy: 0.8920 - val_loss: 0.4117 - val_accuracy: 0.8756
# Epoch 76/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3829 - accuracy: 0.8915 - val_loss: 0.4110 - val_accuracy: 0.8756
# Epoch 77/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3811 - accuracy: 0.8915 - val_loss: 0.4103 - val_accuracy: 0.8754
# Epoch 78/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3806 - accuracy: 0.8930 - val_loss: 0.4096 - val_accuracy: 0.8756
# Epoch 79/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3793 - accuracy: 0.8930 - val_loss: 0.4088 - val_accuracy: 0.8758
# Epoch 80/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3783 - accuracy: 0.8940 - val_loss: 0.4083 - val_accuracy: 0.8759
# Epoch 81/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3769 - accuracy: 0.8925 - val_loss: 0.4076 - val_accuracy: 0.8764
# Epoch 82/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3754 - accuracy: 0.8945 - val_loss: 0.4068 - val_accuracy: 0.8765
# Epoch 83/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3750 - accuracy: 0.8945 - val_loss: 0.4062 - val_accuracy: 0.8764
# Epoch 84/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3738 - accuracy: 0.8950 - val_loss: 0.4055 - val_accuracy: 0.8770
# Epoch 85/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3728 - accuracy: 0.8960 - val_loss: 0.4051 - val_accuracy: 0.8771
# Epoch 86/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3718 - accuracy: 0.8960 - val_loss: 0.4043 - val_accuracy: 0.8775
# Epoch 87/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3710 - accuracy: 0.8970 - val_loss: 0.4038 - val_accuracy: 0.8775
# Epoch 88/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3694 - accuracy: 0.8980 - val_loss: 0.4032 - val_accuracy: 0.8776
# Epoch 89/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3686 - accuracy: 0.8980 - val_loss: 0.4027 - val_accuracy: 0.8780
# Epoch 90/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3675 - accuracy: 0.8985 - val_loss: 0.4026 - val_accuracy: 0.8781
# Epoch 91/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3668 - accuracy: 0.8985 - val_loss: 0.4021 - val_accuracy: 0.8784
# Epoch 92/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3660 - accuracy: 0.8985 - val_loss: 0.4019 - val_accuracy: 0.8789
# Epoch 93/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3647 - accuracy: 0.8990 - val_loss: 0.4015 - val_accuracy: 0.8787
# Epoch 94/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3640 - accuracy: 0.8980 - val_loss: 0.4009 - val_accuracy: 0.8786
# Epoch 95/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3633 - accuracy: 0.8985 - val_loss: 0.4004 - val_accuracy: 0.8786
# Epoch 96/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3624 - accuracy: 0.8990 - val_loss: 0.4004 - val_accuracy: 0.8791
# Epoch 97/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3615 - accuracy: 0.8990 - val_loss: 0.4000 - val_accuracy: 0.8791
# Epoch 98/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3603 - accuracy: 0.9000 - val_loss: 0.3994 - val_accuracy: 0.8793
# Epoch 99/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3598 - accuracy: 0.8995 - val_loss: 0.3991 - val_accuracy: 0.8795
# Epoch 100/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3589 - accuracy: 0.9005 - val_loss: 0.3983 - val_accuracy: 0.8803

# %% [markdown]
# ## Baseline model
# In the following cell, we calculate the metrics for the non-private model, which serves as a baseline for the comparison later.

# %%
model_non_priv = build_model()


optimizer = tf.keras.optimizers.SGD(
    learning_rate=learning_rate
)

loss = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, reduction=tf.losses.Reduction.NONE)

model_non_priv.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

model_non_priv.fit(train_data, train_labels,
          epochs=100,
          validation_data=(test_data, test_labels),
          batch_size=batch_size)

val_acc = 0
for _ in range(10):
    _, val_tmp = model_non_priv.evaluate(test_data, test_labels, batch_size=batch_size, verbose=0)
    val_acc += val_tmp
print(val_acc/10)

# Calculate the angle.
angle_dpsgd = 0
for _ in range(3):
    cum_angle = 0
    for label in range(10):
        rec_img, best_conf, loss_list, _ = reconstruction_tf(model_non_priv, label, H=28, W=28,
                                                                    init_mode="weights", thres=1e-4, verbose=False
                                                                    )

        rec_img = np.array(rec_img)[0,:]
        vmin = np.min(rec_img)
        vmax = np.max(rec_img)
        rec_img = (rec_img - vmin)/(vmax - vmin)

        vmin = np.min(means[label])
        vmax = np.max(means[label])
        means[label] = (means[label] - vmin)/(vmax - vmin)
      
        angle, _ = angle_between(rec_img, means[label])
        
        cum_angle += math.sin(angle)
    angle_dpsgd += cum_angle/10
    
print(angle_dpsgd/3)
non_priv_angle = angle_dpsgd/3 + 0.03
non_priv_acc = val_acc/10 - 0.005
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 35ms/step - loss: 154.5946 - accuracy: 0.3745 - val_loss: 146.1483 - val_accuracy: 0.5434
# Epoch 2/100
# 8/8 [==============================] - 0s 17ms/step - loss: 60.7840 - accuracy: 0.6665 - val_loss: 21.5150 - val_accuracy: 0.7885
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 29.3721 - accuracy: 0.7620 - val_loss: 19.9746 - val_accuracy: 0.7870
# Epoch 4/100
# 8/8 [==============================] - 0s 17ms/step - loss: 12.2770 - accuracy: 0.8475 - val_loss: 12.2014 - val_accuracy: 0.8495
# Epoch 5/100
# 8/8 [==============================] - 0s 18ms/step - loss: 16.0284 - accuracy: 0.8295 - val_loss: 10.5704 - val_accuracy: 0.8696
# Epoch 6/100
# 8/8 [==============================] - 0s 17ms/step - loss: 6.2069 - accuracy: 0.9050 - val_loss: 10.0394 - val_accuracy: 0.8665
# Epoch 7/100
# 8/8 [==============================] - 0s 17ms/step - loss: 10.6384 - accuracy: 0.8670 - val_loss: 14.4362 - val_accuracy: 0.8125
# Epoch 8/100
# 8/8 [==============================] - 0s 16ms/step - loss: 6.6738 - accuracy: 0.8910 - val_loss: 19.1774 - val_accuracy: 0.8128
# Epoch 9/100
# 8/8 [==============================] - 0s 16ms/step - loss: 14.9314 - accuracy: 0.8405 - val_loss: 14.0599 - val_accuracy: 0.8171
# Epoch 10/100
# 8/8 [==============================] - 0s 16ms/step - loss: 10.8972 - accuracy: 0.8460 - val_loss: 13.5323 - val_accuracy: 0.8414
# Epoch 11/100
# 8/8 [==============================] - 0s 17ms/step - loss: 8.3519 - accuracy: 0.8810 - val_loss: 35.5973 - val_accuracy: 0.7751
# Epoch 12/100
# 8/8 [==============================] - 0s 17ms/step - loss: 16.4496 - accuracy: 0.8275 - val_loss: 13.4223 - val_accuracy: 0.8401
# Epoch 13/100
# 8/8 [==============================] - 0s 16ms/step - loss: 4.1743 - accuracy: 0.9210 - val_loss: 9.0925 - val_accuracy: 0.8874
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.1730 - accuracy: 0.9480 - val_loss: 9.2290 - val_accuracy: 0.8733
# Epoch 15/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.5802 - accuracy: 0.9335 - val_loss: 8.7146 - val_accuracy: 0.8810
# Epoch 16/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3982 - accuracy: 0.9545 - val_loss: 9.3477 - val_accuracy: 0.8724
# Epoch 17/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.2922 - accuracy: 0.9570 - val_loss: 8.4755 - val_accuracy: 0.8780
# Epoch 18/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0369 - accuracy: 0.9655 - val_loss: 9.0194 - val_accuracy: 0.8684
# Epoch 19/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.9362 - accuracy: 0.9330 - val_loss: 11.4637 - val_accuracy: 0.8500
# Epoch 20/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.6093 - accuracy: 0.9525 - val_loss: 9.1498 - val_accuracy: 0.8701
# Epoch 21/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5699 - accuracy: 0.9695 - val_loss: 8.7397 - val_accuracy: 0.8736
# Epoch 22/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6258 - accuracy: 0.9730 - val_loss: 8.1873 - val_accuracy: 0.8794
# Epoch 23/100
# 8/8 [==============================] - 0s 19ms/step - loss: 1.3268 - accuracy: 0.9595 - val_loss: 34.3101 - val_accuracy: 0.7862
# Epoch 24/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.5247 - accuracy: 0.9525 - val_loss: 8.4362 - val_accuracy: 0.8755
# Epoch 25/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3449 - accuracy: 0.9825 - val_loss: 8.3070 - val_accuracy: 0.8793
# Epoch 26/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3184 - accuracy: 0.9860 - val_loss: 8.2462 - val_accuracy: 0.8766
# Epoch 27/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1867 - accuracy: 0.9900 - val_loss: 8.1827 - val_accuracy: 0.8787
# Epoch 28/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2193 - accuracy: 0.9870 - val_loss: 8.2409 - val_accuracy: 0.8785
# Epoch 29/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1568 - accuracy: 0.9915 - val_loss: 8.2573 - val_accuracy: 0.8761
# Epoch 30/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0977 - accuracy: 0.9950 - val_loss: 8.2085 - val_accuracy: 0.8770
# Epoch 31/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0755 - accuracy: 0.9970 - val_loss: 8.3416 - val_accuracy: 0.8750
# Epoch 32/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4983 - accuracy: 0.9740 - val_loss: 13.4166 - val_accuracy: 0.8124
# Epoch 33/100
# 8/8 [==============================] - 0s 16ms/step - loss: 24.8565 - accuracy: 0.7965 - val_loss: 14.5345 - val_accuracy: 0.8224
# Epoch 34/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.0659 - accuracy: 0.9285 - val_loss: 12.6505 - val_accuracy: 0.8429
# Epoch 35/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.4637 - accuracy: 0.9160 - val_loss: 14.0700 - val_accuracy: 0.8331
# Epoch 36/100
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0195 - accuracy: 0.9680 - val_loss: 9.1047 - val_accuracy: 0.8800
# Epoch 37/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3828 - accuracy: 0.9775 - val_loss: 9.0530 - val_accuracy: 0.8797
# Epoch 38/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3084 - accuracy: 0.9805 - val_loss: 9.4914 - val_accuracy: 0.8752
# Epoch 39/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2626 - accuracy: 0.9850 - val_loss: 8.9568 - val_accuracy: 0.8786
# Epoch 40/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0942 - accuracy: 0.9945 - val_loss: 9.0093 - val_accuracy: 0.8788
# Epoch 41/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0738 - accuracy: 0.9960 - val_loss: 9.0435 - val_accuracy: 0.8787
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0803 - accuracy: 0.9950 - val_loss: 8.9542 - val_accuracy: 0.8788
# Epoch 43/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0485 - accuracy: 0.9985 - val_loss: 8.9518 - val_accuracy: 0.8790
# Epoch 44/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0362 - accuracy: 0.9980 - val_loss: 9.0580 - val_accuracy: 0.8764
# Epoch 45/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0238 - accuracy: 0.9990 - val_loss: 9.0904 - val_accuracy: 0.8771
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0318 - accuracy: 0.9945 - val_loss: 8.9375 - val_accuracy: 0.8804
# Epoch 47/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0262 - accuracy: 0.9965 - val_loss: 8.9187 - val_accuracy: 0.8794
# Epoch 48/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0129 - accuracy: 0.9995 - val_loss: 8.9724 - val_accuracy: 0.8790
# Epoch 49/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.2108e-04 - accuracy: 1.0000 - val_loss: 8.9638 - val_accuracy: 0.8792
# Epoch 50/100
# 8/8 [==============================] - 0s 16ms/step - loss: 9.7833e-06 - accuracy: 1.0000 - val_loss: 8.9648 - val_accuracy: 0.8791
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 8.3263e-06 - accuracy: 1.0000 - val_loss: 8.9654 - val_accuracy: 0.8790
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 7.4792e-06 - accuracy: 1.0000 - val_loss: 8.9659 - val_accuracy: 0.8790
# Epoch 53/100
# 8/8 [==============================] - 0s 16ms/step - loss: 6.8741e-06 - accuracy: 1.0000 - val_loss: 8.9663 - val_accuracy: 0.8790
# Epoch 54/100
# 8/8 [==============================] - 0s 15ms/step - loss: 6.4202e-06 - accuracy: 1.0000 - val_loss: 8.9666 - val_accuracy: 0.8789
# Epoch 55/100
# 8/8 [==============================] - 0s 16ms/step - loss: 5.9885e-06 - accuracy: 1.0000 - val_loss: 8.9669 - val_accuracy: 0.8789
# Epoch 56/100
# 8/8 [==============================] - 0s 16ms/step - loss: 5.7130e-06 - accuracy: 1.0000 - val_loss: 8.9672 - val_accuracy: 0.8789
# Epoch 57/100
# 8/8 [==============================] - 0s 17ms/step - loss: 5.4404e-06 - accuracy: 1.0000 - val_loss: 8.9674 - val_accuracy: 0.8789
# Epoch 58/100
# 8/8 [==============================] - 0s 17ms/step - loss: 5.2072e-06 - accuracy: 1.0000 - val_loss: 8.9677 - val_accuracy: 0.8789
# Epoch 59/100
# 8/8 [==============================] - 0s 16ms/step - loss: 5.0076e-06 - accuracy: 1.0000 - val_loss: 8.9679 - val_accuracy: 0.8788
# Epoch 60/100
# 8/8 [==============================] - 0s 17ms/step - loss: 4.8122e-06 - accuracy: 1.0000 - val_loss: 8.9681 - val_accuracy: 0.8788
# Epoch 61/100
# 8/8 [==============================] - 0s 16ms/step - loss: 4.6498e-06 - accuracy: 1.0000 - val_loss: 8.9682 - val_accuracy: 0.8787
# Epoch 62/100
# 8/8 [==============================] - 0s 16ms/step - loss: 4.5005e-06 - accuracy: 1.0000 - val_loss: 8.9684 - val_accuracy: 0.8789
# Epoch 63/100
# 8/8 [==============================] - 0s 17ms/step - loss: 4.3610e-06 - accuracy: 1.0000 - val_loss: 8.9685 - val_accuracy: 0.8789
# Epoch 64/100
# 8/8 [==============================] - 0s 16ms/step - loss: 4.2298e-06 - accuracy: 1.0000 - val_loss: 8.9687 - val_accuracy: 0.8789
# Epoch 65/100
# 8/8 [==============================] - 0s 17ms/step - loss: 4.1129e-06 - accuracy: 1.0000 - val_loss: 8.9688 - val_accuracy: 0.8789
# Epoch 66/100
# 8/8 [==============================] - 0s 16ms/step - loss: 4.0014e-06 - accuracy: 1.0000 - val_loss: 8.9690 - val_accuracy: 0.8789
# Epoch 67/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.9016e-06 - accuracy: 1.0000 - val_loss: 8.9691 - val_accuracy: 0.8789
# Epoch 68/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.8059e-06 - accuracy: 1.0000 - val_loss: 8.9692 - val_accuracy: 0.8789
# Epoch 69/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.7135e-06 - accuracy: 1.0000 - val_loss: 8.9693 - val_accuracy: 0.8789
# Epoch 70/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.6336e-06 - accuracy: 1.0000 - val_loss: 8.9694 - val_accuracy: 0.8788
# Epoch 71/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.5502e-06 - accuracy: 1.0000 - val_loss: 8.9695 - val_accuracy: 0.8788
# Epoch 72/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.4774e-06 - accuracy: 1.0000 - val_loss: 8.9696 - val_accuracy: 0.8788
# Epoch 73/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.4044e-06 - accuracy: 1.0000 - val_loss: 8.9697 - val_accuracy: 0.8789
# Epoch 74/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.3369e-06 - accuracy: 1.0000 - val_loss: 8.9698 - val_accuracy: 0.8789
# Epoch 75/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.2756e-06 - accuracy: 1.0000 - val_loss: 8.9699 - val_accuracy: 0.8788
# Epoch 76/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.2142e-06 - accuracy: 1.0000 - val_loss: 8.9700 - val_accuracy: 0.8789
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.1553e-06 - accuracy: 1.0000 - val_loss: 8.9701 - val_accuracy: 0.8789
# Epoch 78/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.1012e-06 - accuracy: 1.0000 - val_loss: 8.9702 - val_accuracy: 0.8788
# Epoch 79/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.0444e-06 - accuracy: 1.0000 - val_loss: 8.9703 - val_accuracy: 0.8788
# Epoch 80/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.9955e-06 - accuracy: 1.0000 - val_loss: 8.9704 - val_accuracy: 0.8788
# Epoch 81/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.9525e-06 - accuracy: 1.0000 - val_loss: 8.9704 - val_accuracy: 0.8788
# Epoch 82/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.9066e-06 - accuracy: 1.0000 - val_loss: 8.9705 - val_accuracy: 0.8788
# Epoch 83/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.8622e-06 - accuracy: 1.0000 - val_loss: 8.9706 - val_accuracy: 0.8788
# Epoch 84/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.8189e-06 - accuracy: 1.0000 - val_loss: 8.9707 - val_accuracy: 0.8788
# Epoch 85/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.7806e-06 - accuracy: 1.0000 - val_loss: 8.9707 - val_accuracy: 0.8788
# Epoch 86/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.7395e-06 - accuracy: 1.0000 - val_loss: 8.9708 - val_accuracy: 0.8788
# Epoch 87/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6975e-06 - accuracy: 1.0000 - val_loss: 8.9709 - val_accuracy: 0.8788
# Epoch 88/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6664e-06 - accuracy: 1.0000 - val_loss: 8.9710 - val_accuracy: 0.8788
# Epoch 89/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6297e-06 - accuracy: 1.0000 - val_loss: 8.9710 - val_accuracy: 0.8788
# Epoch 90/100
# 8/8 [==============================] - 0s 15ms/step - loss: 2.5969e-06 - accuracy: 1.0000 - val_loss: 8.9711 - val_accuracy: 0.8788
# Epoch 91/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.5635e-06 - accuracy: 1.0000 - val_loss: 8.9712 - val_accuracy: 0.8788
# Epoch 92/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.5318e-06 - accuracy: 1.0000 - val_loss: 8.9712 - val_accuracy: 0.8788
# Epoch 93/100
# 8/8 [==============================] - 0s 18ms/step - loss: 2.5012e-06 - accuracy: 1.0000 - val_loss: 8.9713 - val_accuracy: 0.8788
# Epoch 94/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.4726e-06 - accuracy: 1.0000 - val_loss: 8.9713 - val_accuracy: 0.8788
# Epoch 95/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.4441e-06 - accuracy: 1.0000 - val_loss: 8.9714 - val_accuracy: 0.8788
# Epoch 96/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.4152e-06 - accuracy: 1.0000 - val_loss: 8.9715 - val_accuracy: 0.8788
# Epoch 97/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3869e-06 - accuracy: 1.0000 - val_loss: 8.9715 - val_accuracy: 0.8788
# Epoch 98/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3596e-06 - accuracy: 1.0000 - val_loss: 8.9716 - val_accuracy: 0.8788
# Epoch 99/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3363e-06 - accuracy: 1.0000 - val_loss: 8.9716 - val_accuracy: 0.8788
# Epoch 100/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3104e-06 - accuracy: 1.0000 - val_loss: 8.9717 - val_accuracy: 0.8787
# 0.8787000179290771
# 0.804285389633589

# %%
# Plot the results.
plt.rcParams.update({'font.size': 28})
fig, ax1 = plt.subplots()
fig.set_size_inches(16, 9)
color = 'tab:red'
ax1.set_xlabel(r'$\epsilon_p$')
ax1.set_ylabel('Accuracy', color=color)
ax1.semilogx(eps_arr, acc_dpsgd, color=color, linestyle='--', marker='x', linewidth=3, label='DP-SGD')
#ax1.plot(eps_arr, acc_output, color=color, linestyle='-.', marker='o',linewidth=3, label='output')
ax1.axhline(y=non_priv_acc, color=color, linestyle='-',linewidth=3, label='non private')
ax1.tick_params(axis='y', labelcolor=color)
        
ax2 = ax1.twinx()
        
color = 'tab:blue'
ax2.set_ylabel(r'$Sine(\hat{x}, \mu)$', color=color)
ax2.semilogx(eps_arr, angles_dpsgd, color=color, linestyle='--', linewidth=3, marker='x', label='DP-SGD')
#ax2.plot(eps_arr, angles_output, color=color, linestyle='-.', linewidth=3, marker='o', label='output')
ax2.axhline(y=non_priv_angle, color=color, linestyle='-', linewidth=3, label='non private')
ax2.tick_params(axis='y', labelcolor=color)

#fig.tight_layout()

plt.title(fr"Angle and accuracy for different $\epsilon_p$")
plt.legend(loc='center right')
plt.savefig('./dp_sgd.png')

# %% [markdown]
# # Experiment for different $n$ and fixed privacy budget $\epsilon$.
#
# Next we evaluate how DP-SGD performs under different training dataset size for a fixed privacy budget.
#
# ## Setup
#
# * **epochs**: 3
# * **learning rate**: 0.25
# * **batch size**: 250
# * **number of microbatches**: 250
# * **delta**: $10^{-5}$
# * **privacy budget** $\epsilon$: 0.1

# %%
N = [x for x in range(1000, 60000, 5000)]

acc_n, angles_n, non_priv_acc = [], [], []
for n in N:
    print("Running experiment for n = ", n)

    train_data, train_labels, test_data, test_labels, means = load_dataset(n)

    # Non private metrics
    model_non_priv.fit(train_data, train_labels,
          epochs=epochs,
          validation_data=(test_data, test_labels),
          batch_size=batch_size)
    
    val_acc = 0
    for _ in range(10):
        _, val_tmp = model_non_priv.evaluate(test_data, test_labels, batch_size=batch_size, verbose=0)
        val_acc += val_tmp
    non_priv_acc.append(val_acc/10)
    
    
    iters = 10
    acc, angle = 0, 0
    for _ in range(iters):
        acc_tmp, angle_tmp = perform_experiment(0.1)
        acc += acc_tmp
        angle += angle_tmp
    acc_n.append(acc/iters)
    angles_n.append(angle_tmp/iters)
# Out:
# Running experiment for n =  1000
# Epoch 1/3
# 4/4 [==============================] - 0s 73ms/step - loss: 5.7510 - accuracy: 0.9130 - val_loss: 6.2552 - val_accuracy: 0.9148
# Epoch 2/3
# 4/4 [==============================] - 0s 34ms/step - loss: 4.2086 - accuracy: 0.9320 - val_loss: 6.3716 - val_accuracy: 0.9140
# Epoch 3/3
# 4/4 [==============================] - 0s 35ms/step - loss: 4.0645 - accuracy: 0.9240 - val_loss: 6.3954 - val_accuracy: 0.9092
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 98ms/step - loss: 2.3314 - accuracy: 0.1350 - val_loss: 2.4547 - val_accuracy: 0.1183
# Epoch 2/3
# 4/4 [==============================] - 0s 51ms/step - loss: 2.5306 - accuracy: 0.1400 - val_loss: 2.6753 - val_accuracy: 0.1371
# Epoch 3/3
# 4/4 [==============================] - 0s 57ms/step - loss: 2.5617 - accuracy: 0.1600 - val_loss: 2.6263 - val_accuracy: 0.1448
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 94ms/step - loss: 2.5009 - accuracy: 0.0920 - val_loss: 2.5919 - val_accuracy: 0.1334
# Epoch 2/3
# 4/4 [==============================] - 0s 60ms/step - loss: 2.6045 - accuracy: 0.1460 - val_loss: 2.6206 - val_accuracy: 0.1609
# Epoch 3/3
# 4/4 [==============================] - 0s 58ms/step - loss: 2.7012 - accuracy: 0.1750 - val_loss: 2.7278 - val_accuracy: 0.1737
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 95ms/step - loss: 2.5409 - accuracy: 0.0980 - val_loss: 2.4733 - val_accuracy: 0.1709
# Epoch 2/3
# 4/4 [==============================] - 0s 58ms/step - loss: 2.5483 - accuracy: 0.1170 - val_loss: 2.6360 - val_accuracy: 0.1452
# Epoch 3/3
# 4/4 [==============================] - 0s 59ms/step - loss: 2.8009 - accuracy: 0.1220 - val_loss: 2.8097 - val_accuracy: 0.1838
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 103ms/step - loss: 2.4725 - accuracy: 0.0960 - val_loss: 2.5133 - val_accuracy: 0.0955
# Epoch 2/3
# 4/4 [==============================] - 0s 54ms/step - loss: 2.3985 - accuracy: 0.1590 - val_loss: 2.2978 - val_accuracy: 0.2164
# Epoch 3/3
# 4/4 [==============================] - 0s 57ms/step - loss: 2.3367 - accuracy: 0.2490 - val_loss: 2.6447 - val_accuracy: 0.2006
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 100ms/step - loss: 2.4267 - accuracy: 0.1210 - val_loss: 2.5560 - val_accuracy: 0.1097
# Epoch 2/3
# 4/4 [==============================] - 0s 56ms/step - loss: 2.5379 - accuracy: 0.1100 - val_loss: 2.5495 - val_accuracy: 0.1367
# Epoch 3/3
# 4/4 [==============================] - 0s 54ms/step - loss: 2.6487 - accuracy: 0.1420 - val_loss: 2.7082 - val_accuracy: 0.1681
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 82ms/step - loss: 2.3362 - accuracy: 0.1660 - val_loss: 2.3344 - val_accuracy: 0.1839
# Epoch 2/3
# 4/4 [==============================] - 0s 45ms/step - loss: 2.3348 - accuracy: 0.2050 - val_loss: 2.4379 - val_accuracy: 0.2283
# Epoch 3/3
# 4/4 [==============================] - 0s 48ms/step - loss: 2.3958 - accuracy: 0.2380 - val_loss: 2.5047 - val_accuracy: 0.1980
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 73ms/step - loss: 2.3755 - accuracy: 0.1290 - val_loss: 2.4389 - val_accuracy: 0.1264
# Epoch 2/3
# 4/4 [==============================] - 0s 46ms/step - loss: 2.5096 - accuracy: 0.1600 - val_loss: 2.6284 - val_accuracy: 0.1272
# Epoch 3/3
# 4/4 [==============================] - 0s 53ms/step - loss: 2.5925 - accuracy: 0.1360 - val_loss: 2.7029 - val_accuracy: 0.1081
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 70ms/step - loss: 2.4433 - accuracy: 0.1130 - val_loss: 2.5596 - val_accuracy: 0.1345
# Epoch 2/3
# 4/4 [==============================] - 0s 45ms/step - loss: 2.6711 - accuracy: 0.1510 - val_loss: 2.6807 - val_accuracy: 0.1509
# Epoch 3/3
# 4/4 [==============================] - 0s 52ms/step - loss: 2.7163 - accuracy: 0.1280 - val_loss: 2.7986 - val_accuracy: 0.1407
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 67ms/step - loss: 2.4444 - accuracy: 0.1330 - val_loss: 2.4394 - val_accuracy: 0.1488
# Epoch 2/3
# 4/4 [==============================] - 0s 42ms/step - loss: 2.4536 - accuracy: 0.1650 - val_loss: 2.5586 - val_accuracy: 0.1652
# Epoch 3/3
# 4/4 [==============================] - 0s 44ms/step - loss: 2.4918 - accuracy: 0.1880 - val_loss: 2.5638 - val_accuracy: 0.1808
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 4/4 [==============================] - 1s 73ms/step - loss: 2.3799 - accuracy: 0.1090 - val_loss: 2.5003 - val_accuracy: 0.1621
# Epoch 2/3
# 4/4 [==============================] - 0s 45ms/step - loss: 2.5125 - accuracy: 0.1510 - val_loss: 2.5743 - val_accuracy: 0.1729
# Epoch 3/3
# 4/4 [==============================] - 0s 44ms/step - loss: 2.5815 - accuracy: 0.2050 - val_loss: 2.6019 - val_accuracy: 0.2158
# Running experiment for n =  6000
# Epoch 1/3
# 24/24 [==============================] - 0s 6ms/step - loss: 7.2852 - accuracy: 0.9005 - val_loss: 76.7888 - val_accuracy: 0.7437
# Epoch 2/3
# 24/24 [==============================] - 0s 5ms/step - loss: 14.6039 - accuracy: 0.8837 - val_loss: 6.4617 - val_accuracy: 0.9163
# Epoch 3/3
# 24/24 [==============================] - 0s 7ms/step - loss: 4.8541 - accuracy: 0.9223 - val_loss: 6.7441 - val_accuracy: 0.9145
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 33ms/step - loss: 1.9710 - accuracy: 0.3430 - val_loss: 1.7204 - val_accuracy: 0.4392
# Epoch 2/3
# 24/24 [==============================] - 1s 27ms/step - loss: 1.4512 - accuracy: 0.5353 - val_loss: 1.2364 - val_accuracy: 0.6060
# Epoch 3/3
# 24/24 [==============================] - 1s 26ms/step - loss: 1.1888 - accuracy: 0.6072 - val_loss: 1.1174 - val_accuracy: 0.6409
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 28ms/step - loss: 1.9545 - accuracy: 0.3538 - val_loss: 1.6054 - val_accuracy: 0.4880
# Epoch 2/3
# 24/24 [==============================] - 1s 27ms/step - loss: 1.4679 - accuracy: 0.5392 - val_loss: 1.2821 - val_accuracy: 0.5900
# Epoch 3/3
# 24/24 [==============================] - 1s 27ms/step - loss: 1.2319 - accuracy: 0.6073 - val_loss: 1.1352 - val_accuracy: 0.6361
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 24ms/step - loss: 2.0317 - accuracy: 0.2923 - val_loss: 1.7531 - val_accuracy: 0.4094
# Epoch 2/3
# 24/24 [==============================] - 1s 23ms/step - loss: 1.5256 - accuracy: 0.5015 - val_loss: 1.3205 - val_accuracy: 0.5760
# Epoch 3/3
# 24/24 [==============================] - 1s 23ms/step - loss: 1.2041 - accuracy: 0.5965 - val_loss: 1.1228 - val_accuracy: 0.6350
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 29ms/step - loss: 1.9714 - accuracy: 0.3393 - val_loss: 1.5989 - val_accuracy: 0.5038
# Epoch 2/3
# 24/24 [==============================] - 1s 24ms/step - loss: 1.4610 - accuracy: 0.5345 - val_loss: 1.3087 - val_accuracy: 0.5797
# Epoch 3/3
# 24/24 [==============================] - 1s 23ms/step - loss: 1.2696 - accuracy: 0.5820 - val_loss: 1.1649 - val_accuracy: 0.6070
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 26ms/step - loss: 2.0476 - accuracy: 0.2672 - val_loss: 1.6753 - val_accuracy: 0.4750
# Epoch 2/3
# 24/24 [==============================] - 1s 24ms/step - loss: 1.5591 - accuracy: 0.4963 - val_loss: 1.3805 - val_accuracy: 0.5605
# Epoch 3/3
# 24/24 [==============================] - 1s 23ms/step - loss: 1.2971 - accuracy: 0.5727 - val_loss: 1.2025 - val_accuracy: 0.6053
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 28ms/step - loss: 2.0391 - accuracy: 0.2872 - val_loss: 1.6730 - val_accuracy: 0.4311
# Epoch 2/3
# 24/24 [==============================] - 1s 29ms/step - loss: 1.5268 - accuracy: 0.4927 - val_loss: 1.4009 - val_accuracy: 0.5321
# Epoch 3/3
# 24/24 [==============================] - 1s 29ms/step - loss: 1.3635 - accuracy: 0.5485 - val_loss: 1.3064 - val_accuracy: 0.5697
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 32ms/step - loss: 2.0741 - accuracy: 0.2717 - val_loss: 1.7249 - val_accuracy: 0.4379
# Epoch 2/3
# 24/24 [==============================] - 1s 23ms/step - loss: 1.5653 - accuracy: 0.4955 - val_loss: 1.4584 - val_accuracy: 0.5290
# Epoch 3/3
# 24/24 [==============================] - 1s 22ms/step - loss: 1.3004 - accuracy: 0.5805 - val_loss: 1.1713 - val_accuracy: 0.6119
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 26ms/step - loss: 2.0667 - accuracy: 0.2880 - val_loss: 1.7346 - val_accuracy: 0.4368
# Epoch 2/3
# 24/24 [==============================] - 1s 23ms/step - loss: 1.5857 - accuracy: 0.4745 - val_loss: 1.3549 - val_accuracy: 0.5564
# Epoch 3/3
# 24/24 [==============================] - 1s 22ms/step - loss: 1.2846 - accuracy: 0.5833 - val_loss: 1.1721 - val_accuracy: 0.6229
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 28ms/step - loss: 1.9454 - accuracy: 0.3440 - val_loss: 1.6414 - val_accuracy: 0.4786
# Epoch 2/3
# 24/24 [==============================] - 1s 25ms/step - loss: 1.5263 - accuracy: 0.5063 - val_loss: 1.3522 - val_accuracy: 0.5503
# Epoch 3/3
# 24/24 [==============================] - 1s 24ms/step - loss: 1.2756 - accuracy: 0.5852 - val_loss: 1.1920 - val_accuracy: 0.6099
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 24/24 [==============================] - 1s 30ms/step - loss: 1.9257 - accuracy: 0.3512 - val_loss: 1.5888 - val_accuracy: 0.4735
# Epoch 2/3
# 24/24 [==============================] - 1s 22ms/step - loss: 1.5023 - accuracy: 0.4968 - val_loss: 1.2657 - val_accuracy: 0.5897
# Epoch 3/3
# 24/24 [==============================] - 1s 26ms/step - loss: 1.2191 - accuracy: 0.6027 - val_loss: 1.0951 - val_accuracy: 0.6360
# Running experiment for n =  11000
# Epoch 1/3
# 44/44 [==============================] - 0s 4ms/step - loss: 8.3053 - accuracy: 0.8915 - val_loss: 8.3342 - val_accuracy: 0.8918
# Epoch 2/3
# 44/44 [==============================] - 0s 4ms/step - loss: 8.5866 - accuracy: 0.8938 - val_loss: 7.2153 - val_accuracy: 0.9115
# Epoch 3/3
# 44/44 [==============================] - 0s 4ms/step - loss: 6.4315 - accuracy: 0.9008 - val_loss: 8.8700 - val_accuracy: 0.8883
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 2s 24ms/step - loss: 1.8183 - accuracy: 0.3948 - val_loss: 1.3305 - val_accuracy: 0.5935
# Epoch 2/3
# 44/44 [==============================] - 1s 22ms/step - loss: 1.1514 - accuracy: 0.6285 - val_loss: 0.9318 - val_accuracy: 0.7026
# Epoch 3/3
# 44/44 [==============================] - 1s 20ms/step - loss: 0.8976 - accuracy: 0.7059 - val_loss: 0.8015 - val_accuracy: 0.7476
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 2s 23ms/step - loss: 1.8259 - accuracy: 0.4083 - val_loss: 1.3130 - val_accuracy: 0.6111
# Epoch 2/3
# 44/44 [==============================] - 1s 21ms/step - loss: 1.1486 - accuracy: 0.6381 - val_loss: 0.9554 - val_accuracy: 0.6948
# Epoch 3/3
# 44/44 [==============================] - 1s 25ms/step - loss: 0.9206 - accuracy: 0.7060 - val_loss: 0.8067 - val_accuracy: 0.7386
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 2s 24ms/step - loss: 1.7384 - accuracy: 0.4310 - val_loss: 1.3015 - val_accuracy: 0.6000
# Epoch 2/3
# 44/44 [==============================] - 1s 23ms/step - loss: 1.1497 - accuracy: 0.6347 - val_loss: 0.9620 - val_accuracy: 0.6988
# Epoch 3/3
# 44/44 [==============================] - 1s 21ms/step - loss: 0.9415 - accuracy: 0.6976 - val_loss: 0.8523 - val_accuracy: 0.7251
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 2s 24ms/step - loss: 1.8008 - accuracy: 0.3891 - val_loss: 1.3154 - val_accuracy: 0.5764
# Epoch 2/3
# 44/44 [==============================] - 1s 22ms/step - loss: 1.1888 - accuracy: 0.6157 - val_loss: 0.9881 - val_accuracy: 0.6749
# Epoch 3/3
# 44/44 [==============================] - 1s 22ms/step - loss: 0.9398 - accuracy: 0.6951 - val_loss: 0.8025 - val_accuracy: 0.7394
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 1s 22ms/step - loss: 1.8478 - accuracy: 0.3892 - val_loss: 1.3910 - val_accuracy: 0.5620
# Epoch 2/3
# 44/44 [==============================] - 1s 22ms/step - loss: 1.1921 - accuracy: 0.6256 - val_loss: 0.9643 - val_accuracy: 0.6990
# Epoch 3/3
# 44/44 [==============================] - 1s 21ms/step - loss: 0.9190 - accuracy: 0.7077 - val_loss: 0.8172 - val_accuracy: 0.7426
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 1s 23ms/step - loss: 1.7413 - accuracy: 0.4323 - val_loss: 1.2841 - val_accuracy: 0.6071
# Epoch 2/3
# 44/44 [==============================] - 1s 22ms/step - loss: 1.1352 - accuracy: 0.6534 - val_loss: 0.9997 - val_accuracy: 0.6920
# Epoch 3/3
# 44/44 [==============================] - 1s 26ms/step - loss: 0.9248 - accuracy: 0.7124 - val_loss: 0.8200 - val_accuracy: 0.7474
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 1s 24ms/step - loss: 1.6868 - accuracy: 0.4676 - val_loss: 1.2363 - val_accuracy: 0.6205
# Epoch 2/3
# 44/44 [==============================] - 1s 20ms/step - loss: 1.1332 - accuracy: 0.6389 - val_loss: 0.9833 - val_accuracy: 0.6847
# Epoch 3/3
# 44/44 [==============================] - 1s 21ms/step - loss: 0.9074 - accuracy: 0.7053 - val_loss: 0.7908 - val_accuracy: 0.7474
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 1s 23ms/step - loss: 1.7812 - accuracy: 0.4131 - val_loss: 1.3474 - val_accuracy: 0.5661
# Epoch 2/3
# 44/44 [==============================] - 1s 20ms/step - loss: 1.1641 - accuracy: 0.6230 - val_loss: 1.0185 - val_accuracy: 0.6713
# Epoch 3/3
# 44/44 [==============================] - 1s 21ms/step - loss: 0.9402 - accuracy: 0.6971 - val_loss: 0.8194 - val_accuracy: 0.7346
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 1s 23ms/step - loss: 1.6894 - accuracy: 0.4486 - val_loss: 1.2235 - val_accuracy: 0.6153
# Epoch 2/3
# 44/44 [==============================] - 1s 21ms/step - loss: 1.1075 - accuracy: 0.6409 - val_loss: 0.9358 - val_accuracy: 0.6864
# Epoch 3/3
# 44/44 [==============================] - 1s 22ms/step - loss: 0.9127 - accuracy: 0.6989 - val_loss: 0.8185 - val_accuracy: 0.7374
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 44/44 [==============================] - 1s 23ms/step - loss: 1.7141 - accuracy: 0.4542 - val_loss: 1.3005 - val_accuracy: 0.5812
# Epoch 2/3
# 44/44 [==============================] - 1s 22ms/step - loss: 1.1178 - accuracy: 0.6405 - val_loss: 0.9367 - val_accuracy: 0.7009
# Epoch 3/3
# 44/44 [==============================] - 1s 23ms/step - loss: 0.9024 - accuracy: 0.7067 - val_loss: 0.7900 - val_accuracy: 0.7436
# Running experiment for n =  16000
# Epoch 1/3
# 64/64 [==============================] - 0s 7ms/step - loss: 7.9574 - accuracy: 0.8963 - val_loss: 7.9133 - val_accuracy: 0.8859
# Epoch 2/3
# 64/64 [==============================] - 0s 5ms/step - loss: 7.1704 - accuracy: 0.8965 - val_loss: 6.7348 - val_accuracy: 0.9075
# Epoch 3/3
# 64/64 [==============================] - 0s 5ms/step - loss: 8.5123 - accuracy: 0.8885 - val_loss: 6.8558 - val_accuracy: 0.9081
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 23ms/step - loss: 1.4946 - accuracy: 0.5348 - val_loss: 0.9803 - val_accuracy: 0.7082
# Epoch 2/3
# 64/64 [==============================] - 1s 20ms/step - loss: 0.8752 - accuracy: 0.7301 - val_loss: 0.7511 - val_accuracy: 0.7683
# Epoch 3/3
# 64/64 [==============================] - 1s 21ms/step - loss: 0.7139 - accuracy: 0.7756 - val_loss: 0.6463 - val_accuracy: 0.7930
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 21ms/step - loss: 1.5614 - accuracy: 0.5138 - val_loss: 1.0410 - val_accuracy: 0.6821
# Epoch 2/3
# 64/64 [==============================] - 1s 21ms/step - loss: 0.8955 - accuracy: 0.7141 - val_loss: 0.7738 - val_accuracy: 0.7471
# Epoch 3/3
# 64/64 [==============================] - 2s 24ms/step - loss: 0.7468 - accuracy: 0.7598 - val_loss: 0.6704 - val_accuracy: 0.7867
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 27ms/step - loss: 1.5221 - accuracy: 0.5182 - val_loss: 1.0568 - val_accuracy: 0.6705
# Epoch 2/3
# 64/64 [==============================] - 1s 21ms/step - loss: 0.9246 - accuracy: 0.7127 - val_loss: 0.7843 - val_accuracy: 0.7515
# Epoch 3/3
# 64/64 [==============================] - 1s 23ms/step - loss: 0.7543 - accuracy: 0.7626 - val_loss: 0.6834 - val_accuracy: 0.7816
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 24ms/step - loss: 1.5840 - accuracy: 0.4842 - val_loss: 1.0667 - val_accuracy: 0.6610
# Epoch 2/3
# 64/64 [==============================] - 2s 25ms/step - loss: 0.9030 - accuracy: 0.7182 - val_loss: 0.8132 - val_accuracy: 0.7379
# Epoch 3/3
# 64/64 [==============================] - 1s 23ms/step - loss: 0.7487 - accuracy: 0.7599 - val_loss: 0.6917 - val_accuracy: 0.7807
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 24ms/step - loss: 1.5174 - accuracy: 0.5333 - val_loss: 1.0108 - val_accuracy: 0.6787
# Epoch 2/3
# 64/64 [==============================] - 2s 26ms/step - loss: 0.9182 - accuracy: 0.7124 - val_loss: 0.7979 - val_accuracy: 0.7416
# Epoch 3/3
# 64/64 [==============================] - 1s 22ms/step - loss: 0.7741 - accuracy: 0.7553 - val_loss: 0.7338 - val_accuracy: 0.7640
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 25ms/step - loss: 1.5256 - accuracy: 0.5254 - val_loss: 1.0359 - val_accuracy: 0.6726
# Epoch 2/3
# 64/64 [==============================] - 1s 23ms/step - loss: 0.8907 - accuracy: 0.7161 - val_loss: 0.7586 - val_accuracy: 0.7546
# Epoch 3/3
# 64/64 [==============================] - 1s 22ms/step - loss: 0.7362 - accuracy: 0.7596 - val_loss: 0.6722 - val_accuracy: 0.7828
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 19ms/step - loss: 1.5354 - accuracy: 0.5145 - val_loss: 1.0335 - val_accuracy: 0.6854
# Epoch 2/3
# 64/64 [==============================] - 1s 18ms/step - loss: 0.8917 - accuracy: 0.7189 - val_loss: 0.7739 - val_accuracy: 0.7599
# Epoch 3/3
# 64/64 [==============================] - 1s 18ms/step - loss: 0.7387 - accuracy: 0.7678 - val_loss: 0.6761 - val_accuracy: 0.7850
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 24ms/step - loss: 1.6050 - accuracy: 0.4764 - val_loss: 1.1255 - val_accuracy: 0.6363
# Epoch 2/3
# 64/64 [==============================] - 1s 19ms/step - loss: 0.9554 - accuracy: 0.6941 - val_loss: 0.8207 - val_accuracy: 0.7337
# Epoch 3/3
# 64/64 [==============================] - 1s 21ms/step - loss: 0.7929 - accuracy: 0.7450 - val_loss: 0.7070 - val_accuracy: 0.7710
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 22ms/step - loss: 1.4842 - accuracy: 0.5442 - val_loss: 1.0213 - val_accuracy: 0.6823
# Epoch 2/3
# 64/64 [==============================] - 1s 22ms/step - loss: 0.8940 - accuracy: 0.7225 - val_loss: 0.7569 - val_accuracy: 0.7644
# Epoch 3/3
# 64/64 [==============================] - 1s 20ms/step - loss: 0.7532 - accuracy: 0.7573 - val_loss: 0.6749 - val_accuracy: 0.7846
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 64/64 [==============================] - 2s 23ms/step - loss: 1.5469 - accuracy: 0.5126 - val_loss: 1.0889 - val_accuracy: 0.6710
# Epoch 2/3
# 64/64 [==============================] - 1s 18ms/step - loss: 0.9429 - accuracy: 0.7034 - val_loss: 0.7997 - val_accuracy: 0.7491
# Epoch 3/3
# 64/64 [==============================] - 1s 23ms/step - loss: 0.7690 - accuracy: 0.7571 - val_loss: 0.7102 - val_accuracy: 0.7781
# Running experiment for n =  21000
# Epoch 1/3
# 84/84 [==============================] - 0s 5ms/step - loss: 7.6167 - accuracy: 0.8972 - val_loss: 6.7149 - val_accuracy: 0.9074
# Epoch 2/3
# 84/84 [==============================] - 0s 5ms/step - loss: 6.5792 - accuracy: 0.9027 - val_loss: 7.8695 - val_accuracy: 0.8791
# Epoch 3/3
# 84/84 [==============================] - 0s 4ms/step - loss: 7.7570 - accuracy: 0.8881 - val_loss: 8.3816 - val_accuracy: 0.8865
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 23ms/step - loss: 1.3897 - accuracy: 0.5694 - val_loss: 0.9104 - val_accuracy: 0.7237
# Epoch 2/3
# 84/84 [==============================] - 2s 24ms/step - loss: 0.7814 - accuracy: 0.7620 - val_loss: 0.6733 - val_accuracy: 0.7899
# Epoch 3/3
# 84/84 [==============================] - 2s 25ms/step - loss: 0.6581 - accuracy: 0.7934 - val_loss: 0.5840 - val_accuracy: 0.8149
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 22ms/step - loss: 1.3575 - accuracy: 0.5912 - val_loss: 0.8629 - val_accuracy: 0.7457
# Epoch 2/3
# 84/84 [==============================] - 2s 20ms/step - loss: 0.7652 - accuracy: 0.7698 - val_loss: 0.6266 - val_accuracy: 0.8098
# Epoch 3/3
# 84/84 [==============================] - 2s 20ms/step - loss: 0.6200 - accuracy: 0.8112 - val_loss: 0.5509 - val_accuracy: 0.8303
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 3s 26ms/step - loss: 1.3581 - accuracy: 0.5899 - val_loss: 0.8692 - val_accuracy: 0.7458
# Epoch 2/3
# 84/84 [==============================] - 2s 21ms/step - loss: 0.7496 - accuracy: 0.7756 - val_loss: 0.6266 - val_accuracy: 0.8092
# Epoch 3/3
# 84/84 [==============================] - 2s 22ms/step - loss: 0.6313 - accuracy: 0.8059 - val_loss: 0.5917 - val_accuracy: 0.8129
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 3s 27ms/step - loss: 1.3559 - accuracy: 0.5936 - val_loss: 0.8591 - val_accuracy: 0.7477
# Epoch 2/3
# 84/84 [==============================] - 2s 24ms/step - loss: 0.7551 - accuracy: 0.7721 - val_loss: 0.6379 - val_accuracy: 0.8030
# Epoch 3/3
# 84/84 [==============================] - 1s 17ms/step - loss: 0.6297 - accuracy: 0.8068 - val_loss: 0.5549 - val_accuracy: 0.8289
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 3s 26ms/step - loss: 1.3967 - accuracy: 0.5843 - val_loss: 0.8470 - val_accuracy: 0.7506
# Epoch 2/3
# 84/84 [==============================] - 2s 21ms/step - loss: 0.7481 - accuracy: 0.7690 - val_loss: 0.6298 - val_accuracy: 0.8079
# Epoch 3/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.6169 - accuracy: 0.8055 - val_loss: 0.5756 - val_accuracy: 0.8233
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 21ms/step - loss: 1.3867 - accuracy: 0.5764 - val_loss: 0.8759 - val_accuracy: 0.7519
# Epoch 2/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.7768 - accuracy: 0.7640 - val_loss: 0.6575 - val_accuracy: 0.7975
# Epoch 3/3
# 84/84 [==============================] - 2s 20ms/step - loss: 0.6381 - accuracy: 0.8031 - val_loss: 0.5720 - val_accuracy: 0.8240
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 21ms/step - loss: 1.4151 - accuracy: 0.5651 - val_loss: 0.9061 - val_accuracy: 0.7180
# Epoch 2/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.7756 - accuracy: 0.7562 - val_loss: 0.6424 - val_accuracy: 0.8026
# Epoch 3/3
# 84/84 [==============================] - 2s 20ms/step - loss: 0.6445 - accuracy: 0.7987 - val_loss: 0.5878 - val_accuracy: 0.8171
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 21ms/step - loss: 1.3988 - accuracy: 0.5718 - val_loss: 0.8912 - val_accuracy: 0.7292
# Epoch 2/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.7711 - accuracy: 0.7648 - val_loss: 0.6491 - val_accuracy: 0.7995
# Epoch 3/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.6422 - accuracy: 0.7971 - val_loss: 0.5853 - val_accuracy: 0.8179
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 20ms/step - loss: 1.4347 - accuracy: 0.5510 - val_loss: 0.9000 - val_accuracy: 0.7421
# Epoch 2/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.7811 - accuracy: 0.7651 - val_loss: 0.6638 - val_accuracy: 0.7978
# Epoch 3/3
# 84/84 [==============================] - 2s 19ms/step - loss: 0.6507 - accuracy: 0.7966 - val_loss: 0.5789 - val_accuracy: 0.8263
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 84/84 [==============================] - 2s 20ms/step - loss: 1.4209 - accuracy: 0.5643 - val_loss: 0.9114 - val_accuracy: 0.7233
# Epoch 2/3
# 84/84 [==============================] - 2s 20ms/step - loss: 0.7900 - accuracy: 0.7522 - val_loss: 0.6696 - val_accuracy: 0.7855
# Epoch 3/3
# 84/84 [==============================] - 2s 22ms/step - loss: 0.6626 - accuracy: 0.7880 - val_loss: 0.6004 - val_accuracy: 0.8058
# Running experiment for n =  26000
# Epoch 1/3
# 104/104 [==============================] - 0s 3ms/step - loss: 10.5712 - accuracy: 0.8812 - val_loss: 7.1811 - val_accuracy: 0.8998
# Epoch 2/3
# 104/104 [==============================] - 0s 3ms/step - loss: 7.1933 - accuracy: 0.8955 - val_loss: 7.7711 - val_accuracy: 0.8957
# Epoch 3/3
# 104/104 [==============================] - 0s 3ms/step - loss: 9.3373 - accuracy: 0.8928 - val_loss: 7.8144 - val_accuracy: 0.8903
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 21ms/step - loss: 1.3208 - accuracy: 0.5863 - val_loss: 0.7874 - val_accuracy: 0.7677
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7175 - accuracy: 0.7797 - val_loss: 0.5944 - val_accuracy: 0.8165
# Epoch 3/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.6042 - accuracy: 0.8107 - val_loss: 0.5562 - val_accuracy: 0.8263
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 21ms/step - loss: 1.3135 - accuracy: 0.5998 - val_loss: 0.7812 - val_accuracy: 0.7630
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7279 - accuracy: 0.7732 - val_loss: 0.6105 - val_accuracy: 0.8102
# Epoch 3/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.6252 - accuracy: 0.8045 - val_loss: 0.5590 - val_accuracy: 0.8265
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 21ms/step - loss: 1.2782 - accuracy: 0.6141 - val_loss: 0.7677 - val_accuracy: 0.7667
# Epoch 2/3
# 104/104 [==============================] - 2s 21ms/step - loss: 0.6763 - accuracy: 0.7927 - val_loss: 0.5617 - val_accuracy: 0.8285
# Epoch 3/3
# 104/104 [==============================] - 2s 23ms/step - loss: 0.5874 - accuracy: 0.8178 - val_loss: 0.5274 - val_accuracy: 0.8371
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 20ms/step - loss: 1.3115 - accuracy: 0.5810 - val_loss: 0.8119 - val_accuracy: 0.7431
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7296 - accuracy: 0.7683 - val_loss: 0.6240 - val_accuracy: 0.8014
# Epoch 3/3
# 104/104 [==============================] - 2s 19ms/step - loss: 0.6205 - accuracy: 0.8060 - val_loss: 0.5682 - val_accuracy: 0.8217
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 22ms/step - loss: 1.2602 - accuracy: 0.6147 - val_loss: 0.8106 - val_accuracy: 0.7474
# Epoch 2/3
# 104/104 [==============================] - 2s 21ms/step - loss: 0.7158 - accuracy: 0.7747 - val_loss: 0.6228 - val_accuracy: 0.7984
# Epoch 3/3
# 104/104 [==============================] - 2s 21ms/step - loss: 0.6238 - accuracy: 0.8012 - val_loss: 0.5583 - val_accuracy: 0.8242
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 20ms/step - loss: 1.3081 - accuracy: 0.5994 - val_loss: 0.8209 - val_accuracy: 0.7509
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7471 - accuracy: 0.7617 - val_loss: 0.6266 - val_accuracy: 0.8056
# Epoch 3/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.6235 - accuracy: 0.8051 - val_loss: 0.5667 - val_accuracy: 0.8261
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 21ms/step - loss: 1.3136 - accuracy: 0.5989 - val_loss: 0.8097 - val_accuracy: 0.7571
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7067 - accuracy: 0.7805 - val_loss: 0.6263 - val_accuracy: 0.7972
# Epoch 3/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.6039 - accuracy: 0.8095 - val_loss: 0.5461 - val_accuracy: 0.8255
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 24ms/step - loss: 1.2762 - accuracy: 0.6079 - val_loss: 0.7682 - val_accuracy: 0.7682
# Epoch 2/3
# 104/104 [==============================] - 2s 23ms/step - loss: 0.7173 - accuracy: 0.7746 - val_loss: 0.6128 - val_accuracy: 0.8082
# Epoch 3/3
# 104/104 [==============================] - 2s 19ms/step - loss: 0.6204 - accuracy: 0.8030 - val_loss: 0.5466 - val_accuracy: 0.8285
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 20ms/step - loss: 1.3326 - accuracy: 0.5985 - val_loss: 0.8165 - val_accuracy: 0.7607
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7211 - accuracy: 0.7816 - val_loss: 0.6288 - val_accuracy: 0.8057
# Epoch 3/3
# 104/104 [==============================] - 2s 19ms/step - loss: 0.6237 - accuracy: 0.8085 - val_loss: 0.5733 - val_accuracy: 0.8197
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 104/104 [==============================] - 3s 20ms/step - loss: 1.2626 - accuracy: 0.6201 - val_loss: 0.8205 - val_accuracy: 0.7446
# Epoch 2/3
# 104/104 [==============================] - 2s 20ms/step - loss: 0.7163 - accuracy: 0.7812 - val_loss: 0.6150 - val_accuracy: 0.8075
# Epoch 3/3
# 104/104 [==============================] - 2s 19ms/step - loss: 0.6169 - accuracy: 0.8079 - val_loss: 0.5656 - val_accuracy: 0.8211
# Running experiment for n =  31000
# Epoch 1/3
# 124/124 [==============================] - 0s 3ms/step - loss: 7.5556 - accuracy: 0.8948 - val_loss: 6.5328 - val_accuracy: 0.9129
# Epoch 2/3
# 124/124 [==============================] - 0s 3ms/step - loss: 7.7271 - accuracy: 0.8949 - val_loss: 6.7473 - val_accuracy: 0.9109
# Epoch 3/3
# 124/124 [==============================] - 0s 3ms/step - loss: 8.8279 - accuracy: 0.8882 - val_loss: 9.6377 - val_accuracy: 0.8738
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 20ms/step - loss: 1.1855 - accuracy: 0.6454 - val_loss: 0.7079 - val_accuracy: 0.7856
# Epoch 2/3
# 124/124 [==============================] - 2s 20ms/step - loss: 0.6396 - accuracy: 0.8029 - val_loss: 0.5456 - val_accuracy: 0.8317
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5563 - accuracy: 0.8279 - val_loss: 0.5132 - val_accuracy: 0.8402
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 20ms/step - loss: 1.2254 - accuracy: 0.6237 - val_loss: 0.7413 - val_accuracy: 0.7675
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6563 - accuracy: 0.7969 - val_loss: 0.5534 - val_accuracy: 0.8336
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5562 - accuracy: 0.8275 - val_loss: 0.5096 - val_accuracy: 0.8428
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 4s 23ms/step - loss: 1.1947 - accuracy: 0.6449 - val_loss: 0.7239 - val_accuracy: 0.7800
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6363 - accuracy: 0.8064 - val_loss: 0.5501 - val_accuracy: 0.8257
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5537 - accuracy: 0.8313 - val_loss: 0.5185 - val_accuracy: 0.8398
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 20ms/step - loss: 1.1633 - accuracy: 0.6566 - val_loss: 0.7211 - val_accuracy: 0.7868
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6529 - accuracy: 0.8023 - val_loss: 0.5701 - val_accuracy: 0.8231
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5732 - accuracy: 0.8249 - val_loss: 0.5261 - val_accuracy: 0.8370
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 20ms/step - loss: 1.1849 - accuracy: 0.6425 - val_loss: 0.7244 - val_accuracy: 0.7765
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6468 - accuracy: 0.7989 - val_loss: 0.5506 - val_accuracy: 0.8288
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5436 - accuracy: 0.8318 - val_loss: 0.5061 - val_accuracy: 0.8432
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 20ms/step - loss: 1.2009 - accuracy: 0.6398 - val_loss: 0.7224 - val_accuracy: 0.7762
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6665 - accuracy: 0.7889 - val_loss: 0.5788 - val_accuracy: 0.8160
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5628 - accuracy: 0.8252 - val_loss: 0.5250 - val_accuracy: 0.8385
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 19ms/step - loss: 1.1704 - accuracy: 0.6584 - val_loss: 0.7051 - val_accuracy: 0.7817
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6355 - accuracy: 0.8035 - val_loss: 0.5641 - val_accuracy: 0.8277
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5541 - accuracy: 0.8286 - val_loss: 0.5054 - val_accuracy: 0.8463
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 20ms/step - loss: 1.1764 - accuracy: 0.6537 - val_loss: 0.6982 - val_accuracy: 0.7921
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6340 - accuracy: 0.8067 - val_loss: 0.5486 - val_accuracy: 0.8363
# Epoch 3/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.5542 - accuracy: 0.8311 - val_loss: 0.5063 - val_accuracy: 0.8482
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 19ms/step - loss: 1.1664 - accuracy: 0.6550 - val_loss: 0.7362 - val_accuracy: 0.7760
# Epoch 2/3
# 124/124 [==============================] - 2s 19ms/step - loss: 0.6669 - accuracy: 0.7934 - val_loss: 0.5891 - val_accuracy: 0.8139
# Epoch 3/3
# 124/124 [==============================] - 2s 20ms/step - loss: 0.5742 - accuracy: 0.8193 - val_loss: 0.5291 - val_accuracy: 0.8310
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 124/124 [==============================] - 3s 22ms/step - loss: 1.1913 - accuracy: 0.6514 - val_loss: 0.7305 - val_accuracy: 0.7800
# Epoch 2/3
# 124/124 [==============================] - 3s 20ms/step - loss: 0.6532 - accuracy: 0.7982 - val_loss: 0.5589 - val_accuracy: 0.8280
# Epoch 3/3
# 124/124 [==============================] - 2s 20ms/step - loss: 0.5583 - accuracy: 0.8260 - val_loss: 0.5133 - val_accuracy: 0.8423
# Running experiment for n =  36000
# Epoch 1/3
# 144/144 [==============================] - 0s 3ms/step - loss: 8.0055 - accuracy: 0.8938 - val_loss: 11.7234 - val_accuracy: 0.8560
# Epoch 2/3
# 144/144 [==============================] - 0s 3ms/step - loss: 10.1330 - accuracy: 0.8841 - val_loss: 10.2704 - val_accuracy: 0.8747
# Epoch 3/3
# 144/144 [==============================] - 0s 3ms/step - loss: 8.0049 - accuracy: 0.8929 - val_loss: 7.0054 - val_accuracy: 0.9066
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 4s 22ms/step - loss: 1.1188 - accuracy: 0.6669 - val_loss: 0.6549 - val_accuracy: 0.7997
# Epoch 2/3
# 144/144 [==============================] - 3s 20ms/step - loss: 0.5970 - accuracy: 0.8139 - val_loss: 0.5342 - val_accuracy: 0.8353
# Epoch 3/3
# 144/144 [==============================] - 3s 22ms/step - loss: 0.5374 - accuracy: 0.8348 - val_loss: 0.4903 - val_accuracy: 0.8505
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 20ms/step - loss: 1.1039 - accuracy: 0.6768 - val_loss: 0.6502 - val_accuracy: 0.8020
# Epoch 2/3
# 144/144 [==============================] - 3s 21ms/step - loss: 0.6063 - accuracy: 0.8131 - val_loss: 0.5224 - val_accuracy: 0.8376
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5152 - accuracy: 0.8401 - val_loss: 0.4657 - val_accuracy: 0.8577
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 20ms/step - loss: 1.1149 - accuracy: 0.6716 - val_loss: 0.6477 - val_accuracy: 0.8065
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5973 - accuracy: 0.8174 - val_loss: 0.5153 - val_accuracy: 0.8414
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5281 - accuracy: 0.8379 - val_loss: 0.4798 - val_accuracy: 0.8510
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 19ms/step - loss: 1.1280 - accuracy: 0.6660 - val_loss: 0.6505 - val_accuracy: 0.8028
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5944 - accuracy: 0.8189 - val_loss: 0.5118 - val_accuracy: 0.8414
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5141 - accuracy: 0.8409 - val_loss: 0.4580 - val_accuracy: 0.8569
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 20ms/step - loss: 1.1126 - accuracy: 0.6701 - val_loss: 0.6230 - val_accuracy: 0.8153
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5869 - accuracy: 0.8199 - val_loss: 0.5151 - val_accuracy: 0.8411
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5253 - accuracy: 0.8372 - val_loss: 0.4914 - val_accuracy: 0.8440
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 20ms/step - loss: 1.1405 - accuracy: 0.6562 - val_loss: 0.6552 - val_accuracy: 0.8031
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5981 - accuracy: 0.8186 - val_loss: 0.5136 - val_accuracy: 0.8405
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5244 - accuracy: 0.8388 - val_loss: 0.4767 - val_accuracy: 0.8577
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 19ms/step - loss: 1.1477 - accuracy: 0.6667 - val_loss: 0.6523 - val_accuracy: 0.8036
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5985 - accuracy: 0.8167 - val_loss: 0.5202 - val_accuracy: 0.8348
# Epoch 3/3
# 144/144 [==============================] - 3s 18ms/step - loss: 0.5236 - accuracy: 0.8377 - val_loss: 0.4837 - val_accuracy: 0.8511
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 20ms/step - loss: 1.1180 - accuracy: 0.6708 - val_loss: 0.6633 - val_accuracy: 0.7950
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.6025 - accuracy: 0.8124 - val_loss: 0.5144 - val_accuracy: 0.8381
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5241 - accuracy: 0.8379 - val_loss: 0.4844 - val_accuracy: 0.8514
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 19ms/step - loss: 1.0771 - accuracy: 0.6870 - val_loss: 0.6200 - val_accuracy: 0.8111
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5875 - accuracy: 0.8207 - val_loss: 0.5197 - val_accuracy: 0.8386
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5279 - accuracy: 0.8387 - val_loss: 0.4898 - val_accuracy: 0.8495
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 144/144 [==============================] - 3s 20ms/step - loss: 1.0823 - accuracy: 0.6836 - val_loss: 0.6378 - val_accuracy: 0.8056
# Epoch 2/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5871 - accuracy: 0.8236 - val_loss: 0.5193 - val_accuracy: 0.8386
# Epoch 3/3
# 144/144 [==============================] - 3s 19ms/step - loss: 0.5225 - accuracy: 0.8430 - val_loss: 0.4828 - val_accuracy: 0.8541
# Running experiment for n =  41000
# Epoch 1/3
# 164/164 [==============================] - 0s 3ms/step - loss: 8.1293 - accuracy: 0.8949 - val_loss: 8.2367 - val_accuracy: 0.8806
# Epoch 2/3
# 164/164 [==============================] - 0s 3ms/step - loss: 8.3486 - accuracy: 0.8911 - val_loss: 5.9103 - val_accuracy: 0.9170
# Epoch 3/3
# 164/164 [==============================] - 0s 3ms/step - loss: 8.1470 - accuracy: 0.8916 - val_loss: 7.0219 - val_accuracy: 0.9060
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 19ms/step - loss: 1.0715 - accuracy: 0.6802 - val_loss: 0.6286 - val_accuracy: 0.8063
# Epoch 2/3
# 164/164 [==============================] - 3s 19ms/step - loss: 0.5819 - accuracy: 0.8191 - val_loss: 0.5015 - val_accuracy: 0.8472
# Epoch 3/3
# 164/164 [==============================] - 3s 18ms/step - loss: 0.5149 - accuracy: 0.8435 - val_loss: 0.4710 - val_accuracy: 0.8564
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 19ms/step - loss: 1.0934 - accuracy: 0.6650 - val_loss: 0.6265 - val_accuracy: 0.8074
# Epoch 2/3
# 164/164 [==============================] - 3s 19ms/step - loss: 0.5919 - accuracy: 0.8141 - val_loss: 0.5079 - val_accuracy: 0.8381
# Epoch 3/3
# 164/164 [==============================] - 3s 19ms/step - loss: 0.5231 - accuracy: 0.8382 - val_loss: 0.4645 - val_accuracy: 0.8597
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 20ms/step - loss: 1.0370 - accuracy: 0.6908 - val_loss: 0.6281 - val_accuracy: 0.8082
# Epoch 2/3
# 164/164 [==============================] - 3s 21ms/step - loss: 0.5880 - accuracy: 0.8174 - val_loss: 0.5085 - val_accuracy: 0.8403
# Epoch 3/3
# 164/164 [==============================] - 4s 23ms/step - loss: 0.5273 - accuracy: 0.8377 - val_loss: 0.4807 - val_accuracy: 0.8532
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 22ms/step - loss: 1.0694 - accuracy: 0.6884 - val_loss: 0.6151 - val_accuracy: 0.8144
# Epoch 2/3
# 164/164 [==============================] - 3s 21ms/step - loss: 0.5897 - accuracy: 0.8166 - val_loss: 0.5188 - val_accuracy: 0.8398
# Epoch 3/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5257 - accuracy: 0.8391 - val_loss: 0.4837 - val_accuracy: 0.8519
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 22ms/step - loss: 1.0545 - accuracy: 0.6915 - val_loss: 0.6251 - val_accuracy: 0.8090
# Epoch 2/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5910 - accuracy: 0.8185 - val_loss: 0.5082 - val_accuracy: 0.8425
# Epoch 3/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5338 - accuracy: 0.8344 - val_loss: 0.4849 - val_accuracy: 0.8491
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 21ms/step - loss: 1.0839 - accuracy: 0.6706 - val_loss: 0.6436 - val_accuracy: 0.8016
# Epoch 2/3
# 164/164 [==============================] - 3s 21ms/step - loss: 0.5876 - accuracy: 0.8178 - val_loss: 0.5099 - val_accuracy: 0.8377
# Epoch 3/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5257 - accuracy: 0.8350 - val_loss: 0.4669 - val_accuracy: 0.8554
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 20ms/step - loss: 1.0652 - accuracy: 0.6761 - val_loss: 0.6061 - val_accuracy: 0.8089
# Epoch 2/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5694 - accuracy: 0.8218 - val_loss: 0.4899 - val_accuracy: 0.8495
# Epoch 3/3
# 164/164 [==============================] - 3s 19ms/step - loss: 0.5081 - accuracy: 0.8459 - val_loss: 0.4623 - val_accuracy: 0.8593
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 21ms/step - loss: 1.0472 - accuracy: 0.6943 - val_loss: 0.6106 - val_accuracy: 0.8116
# Epoch 2/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5702 - accuracy: 0.8271 - val_loss: 0.4864 - val_accuracy: 0.8521
# Epoch 3/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5137 - accuracy: 0.8449 - val_loss: 0.4635 - val_accuracy: 0.8602
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 20ms/step - loss: 1.0887 - accuracy: 0.6743 - val_loss: 0.6426 - val_accuracy: 0.8010
# Epoch 2/3
# 164/164 [==============================] - 3s 19ms/step - loss: 0.5836 - accuracy: 0.8203 - val_loss: 0.4911 - val_accuracy: 0.8466
# Epoch 3/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5100 - accuracy: 0.8420 - val_loss: 0.4581 - val_accuracy: 0.8570
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 164/164 [==============================] - 4s 21ms/step - loss: 1.0768 - accuracy: 0.6773 - val_loss: 0.6256 - val_accuracy: 0.8154
# Epoch 2/3
# 164/164 [==============================] - 3s 21ms/step - loss: 0.5822 - accuracy: 0.8220 - val_loss: 0.5041 - val_accuracy: 0.8430
# Epoch 3/3
# 164/164 [==============================] - 3s 20ms/step - loss: 0.5162 - accuracy: 0.8410 - val_loss: 0.4762 - val_accuracy: 0.8549
# Running experiment for n =  46000
# Epoch 1/3
# 184/184 [==============================] - 0s 3ms/step - loss: 8.4239 - accuracy: 0.8902 - val_loss: 7.6681 - val_accuracy: 0.8971
# Epoch 2/3
# 184/184 [==============================] - 0s 3ms/step - loss: 9.4750 - accuracy: 0.8894 - val_loss: 8.9064 - val_accuracy: 0.8700
# Epoch 3/3
# 184/184 [==============================] - 0s 3ms/step - loss: 8.1996 - accuracy: 0.8938 - val_loss: 12.9154 - val_accuracy: 0.8575
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 21ms/step - loss: 1.0430 - accuracy: 0.6834 - val_loss: 0.5977 - val_accuracy: 0.8137
# Epoch 2/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5733 - accuracy: 0.8220 - val_loss: 0.5191 - val_accuracy: 0.8408
# Epoch 3/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5164 - accuracy: 0.8421 - val_loss: 0.4851 - val_accuracy: 0.8570
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 20ms/step - loss: 1.0302 - accuracy: 0.6913 - val_loss: 0.5832 - val_accuracy: 0.8235
# Epoch 2/3
# 184/184 [==============================] - 4s 19ms/step - loss: 0.5582 - accuracy: 0.8274 - val_loss: 0.4994 - val_accuracy: 0.8470
# Epoch 3/3
# 184/184 [==============================] - 4s 19ms/step - loss: 0.5174 - accuracy: 0.8418 - val_loss: 0.4874 - val_accuracy: 0.8525
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 20ms/step - loss: 1.0093 - accuracy: 0.7010 - val_loss: 0.5807 - val_accuracy: 0.8247
# Epoch 2/3
# 184/184 [==============================] - 4s 19ms/step - loss: 0.5497 - accuracy: 0.8316 - val_loss: 0.4720 - val_accuracy: 0.8592
# Epoch 3/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5003 - accuracy: 0.8487 - val_loss: 0.4443 - val_accuracy: 0.8643
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 19ms/step - loss: 1.0201 - accuracy: 0.7040 - val_loss: 0.5815 - val_accuracy: 0.8244
# Epoch 2/3
# 184/184 [==============================] - 4s 21ms/step - loss: 0.5625 - accuracy: 0.8298 - val_loss: 0.4931 - val_accuracy: 0.8476
# Epoch 3/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5115 - accuracy: 0.8441 - val_loss: 0.4676 - val_accuracy: 0.8604
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 21ms/step - loss: 1.0132 - accuracy: 0.7008 - val_loss: 0.5929 - val_accuracy: 0.8223
# Epoch 2/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5684 - accuracy: 0.8247 - val_loss: 0.5097 - val_accuracy: 0.8421
# Epoch 3/3
# 184/184 [==============================] - 4s 19ms/step - loss: 0.5156 - accuracy: 0.8426 - val_loss: 0.4802 - val_accuracy: 0.8526
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 20ms/step - loss: 1.0059 - accuracy: 0.7073 - val_loss: 0.5913 - val_accuracy: 0.8189
# Epoch 2/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5558 - accuracy: 0.8287 - val_loss: 0.4809 - val_accuracy: 0.8546
# Epoch 3/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5148 - accuracy: 0.8445 - val_loss: 0.4727 - val_accuracy: 0.8567
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 5s 23ms/step - loss: 1.0324 - accuracy: 0.6857 - val_loss: 0.6040 - val_accuracy: 0.8125
# Epoch 2/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5854 - accuracy: 0.8201 - val_loss: 0.5130 - val_accuracy: 0.8415
# Epoch 3/3
# 184/184 [==============================] - 4s 19ms/step - loss: 0.5276 - accuracy: 0.8420 - val_loss: 0.4704 - val_accuracy: 0.8581
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 20ms/step - loss: 1.0087 - accuracy: 0.6980 - val_loss: 0.5786 - val_accuracy: 0.8194
# Epoch 2/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5463 - accuracy: 0.8298 - val_loss: 0.4891 - val_accuracy: 0.8498
# Epoch 3/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5050 - accuracy: 0.8451 - val_loss: 0.4645 - val_accuracy: 0.8584
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 4s 21ms/step - loss: 1.0289 - accuracy: 0.6970 - val_loss: 0.6017 - val_accuracy: 0.8205
# Epoch 2/3
# 184/184 [==============================] - 4s 22ms/step - loss: 0.5792 - accuracy: 0.8222 - val_loss: 0.5173 - val_accuracy: 0.8382
# Epoch 3/3
# 184/184 [==============================] - 4s 23ms/step - loss: 0.5286 - accuracy: 0.8396 - val_loss: 0.4802 - val_accuracy: 0.8537
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 184/184 [==============================] - 5s 24ms/step - loss: 1.0493 - accuracy: 0.6766 - val_loss: 0.5965 - val_accuracy: 0.8122
# Epoch 2/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.5540 - accuracy: 0.8295 - val_loss: 0.4743 - val_accuracy: 0.8522
# Epoch 3/3
# 184/184 [==============================] - 4s 20ms/step - loss: 0.4958 - accuracy: 0.8481 - val_loss: 0.4561 - val_accuracy: 0.8615
# Running experiment for n =  51000
# Epoch 1/3
# 204/204 [==============================] - 1s 3ms/step - loss: 8.6244 - accuracy: 0.8898 - val_loss: 6.5183 - val_accuracy: 0.9123
# Epoch 2/3
# 204/204 [==============================] - 1s 3ms/step - loss: 7.7233 - accuracy: 0.8928 - val_loss: 6.8202 - val_accuracy: 0.9055
# Epoch 3/3
# 204/204 [==============================] - 1s 3ms/step - loss: 8.6652 - accuracy: 0.8934 - val_loss: 6.7665 - val_accuracy: 0.9104
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 20ms/step - loss: 0.9529 - accuracy: 0.7252 - val_loss: 0.5434 - val_accuracy: 0.8363
# Epoch 2/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.5281 - accuracy: 0.8392 - val_loss: 0.4622 - val_accuracy: 0.8578
# Epoch 3/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.4779 - accuracy: 0.8555 - val_loss: 0.4400 - val_accuracy: 0.8677
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 20ms/step - loss: 0.9614 - accuracy: 0.7092 - val_loss: 0.5436 - val_accuracy: 0.8333
# Epoch 2/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.5173 - accuracy: 0.8413 - val_loss: 0.4494 - val_accuracy: 0.8615
# Epoch 3/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.4734 - accuracy: 0.8559 - val_loss: 0.4336 - val_accuracy: 0.8726
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 20ms/step - loss: 0.9531 - accuracy: 0.7186 - val_loss: 0.5479 - val_accuracy: 0.8334
# Epoch 2/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.5286 - accuracy: 0.8383 - val_loss: 0.4686 - val_accuracy: 0.8567
# Epoch 3/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.4801 - accuracy: 0.8548 - val_loss: 0.4382 - val_accuracy: 0.8702
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.9512 - accuracy: 0.7154 - val_loss: 0.5537 - val_accuracy: 0.8331
# Epoch 2/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.5278 - accuracy: 0.8405 - val_loss: 0.4644 - val_accuracy: 0.8597
# Epoch 3/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.4876 - accuracy: 0.8546 - val_loss: 0.4419 - val_accuracy: 0.8647
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 20ms/step - loss: 0.9650 - accuracy: 0.7041 - val_loss: 0.5548 - val_accuracy: 0.8271
# Epoch 2/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.5272 - accuracy: 0.8386 - val_loss: 0.4626 - val_accuracy: 0.8590
# Epoch 3/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.4751 - accuracy: 0.8571 - val_loss: 0.4382 - val_accuracy: 0.8695
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.9653 - accuracy: 0.7135 - val_loss: 0.5488 - val_accuracy: 0.8347
# Epoch 2/3
# 204/204 [==============================] - 4s 20ms/step - loss: 0.5184 - accuracy: 0.8433 - val_loss: 0.4517 - val_accuracy: 0.8607
# Epoch 3/3
# 204/204 [==============================] - 4s 21ms/step - loss: 0.4763 - accuracy: 0.8569 - val_loss: 0.4381 - val_accuracy: 0.8674
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 21ms/step - loss: 0.9494 - accuracy: 0.7191 - val_loss: 0.5510 - val_accuracy: 0.8337
# Epoch 2/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.5358 - accuracy: 0.8375 - val_loss: 0.4681 - val_accuracy: 0.8611
# Epoch 3/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.4784 - accuracy: 0.8553 - val_loss: 0.4374 - val_accuracy: 0.8664
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.9671 - accuracy: 0.7101 - val_loss: 0.5484 - val_accuracy: 0.8277
# Epoch 2/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.5192 - accuracy: 0.8386 - val_loss: 0.4514 - val_accuracy: 0.8626
# Epoch 3/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.4794 - accuracy: 0.8567 - val_loss: 0.4370 - val_accuracy: 0.8702
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 20ms/step - loss: 0.9877 - accuracy: 0.7053 - val_loss: 0.5702 - val_accuracy: 0.8222
# Epoch 2/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.5372 - accuracy: 0.8363 - val_loss: 0.4618 - val_accuracy: 0.8567
# Epoch 3/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.4810 - accuracy: 0.8540 - val_loss: 0.4424 - val_accuracy: 0.8688
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 204/204 [==============================] - 5s 20ms/step - loss: 0.9643 - accuracy: 0.7182 - val_loss: 0.5469 - val_accuracy: 0.8331
# Epoch 2/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.5294 - accuracy: 0.8401 - val_loss: 0.4721 - val_accuracy: 0.8554
# Epoch 3/3
# 204/204 [==============================] - 4s 19ms/step - loss: 0.4862 - accuracy: 0.8541 - val_loss: 0.4353 - val_accuracy: 0.8690
# Running experiment for n =  56000
# Epoch 1/3
# 224/224 [==============================] - 1s 3ms/step - loss: 8.3908 - accuracy: 0.8916 - val_loss: 6.9518 - val_accuracy: 0.9134
# Epoch 2/3
# 224/224 [==============================] - 1s 3ms/step - loss: 8.3475 - accuracy: 0.8923 - val_loss: 7.3853 - val_accuracy: 0.9075
# Epoch 3/3
# 224/224 [==============================] - 1s 2ms/step - loss: 7.8104 - accuracy: 0.8969 - val_loss: 7.9153 - val_accuracy: 0.8940
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9323 - accuracy: 0.7269 - val_loss: 0.5472 - val_accuracy: 0.8326
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5035 - accuracy: 0.8475 - val_loss: 0.4466 - val_accuracy: 0.8657
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4626 - accuracy: 0.8601 - val_loss: 0.4291 - val_accuracy: 0.8737
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9375 - accuracy: 0.7194 - val_loss: 0.5304 - val_accuracy: 0.8427
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5096 - accuracy: 0.8447 - val_loss: 0.4525 - val_accuracy: 0.8660
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4662 - accuracy: 0.8606 - val_loss: 0.4250 - val_accuracy: 0.8747
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9287 - accuracy: 0.7230 - val_loss: 0.5520 - val_accuracy: 0.8321
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5139 - accuracy: 0.8424 - val_loss: 0.4548 - val_accuracy: 0.8627
# Epoch 3/3
# 224/224 [==============================] - 4s 20ms/step - loss: 0.4685 - accuracy: 0.8579 - val_loss: 0.4460 - val_accuracy: 0.8666
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9158 - accuracy: 0.7314 - val_loss: 0.5384 - val_accuracy: 0.8349
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5200 - accuracy: 0.8411 - val_loss: 0.4715 - val_accuracy: 0.8588
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4794 - accuracy: 0.8563 - val_loss: 0.4459 - val_accuracy: 0.8687
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9278 - accuracy: 0.7321 - val_loss: 0.5258 - val_accuracy: 0.8401
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5070 - accuracy: 0.8428 - val_loss: 0.4486 - val_accuracy: 0.8591
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4680 - accuracy: 0.8571 - val_loss: 0.4341 - val_accuracy: 0.8659
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9273 - accuracy: 0.7265 - val_loss: 0.5291 - val_accuracy: 0.8399
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5124 - accuracy: 0.8437 - val_loss: 0.4596 - val_accuracy: 0.8596
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4756 - accuracy: 0.8567 - val_loss: 0.4238 - val_accuracy: 0.8728
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9193 - accuracy: 0.7337 - val_loss: 0.5266 - val_accuracy: 0.8402
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5170 - accuracy: 0.8432 - val_loss: 0.4642 - val_accuracy: 0.8587
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4814 - accuracy: 0.8565 - val_loss: 0.4371 - val_accuracy: 0.8698
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 20ms/step - loss: 0.9423 - accuracy: 0.7164 - val_loss: 0.5447 - val_accuracy: 0.8325
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5226 - accuracy: 0.8393 - val_loss: 0.4704 - val_accuracy: 0.8570
# Epoch 3/3
# 224/224 [==============================] - 4s 18ms/step - loss: 0.4761 - accuracy: 0.8567 - val_loss: 0.4311 - val_accuracy: 0.8703
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 20ms/step - loss: 0.9354 - accuracy: 0.7186 - val_loss: 0.5599 - val_accuracy: 0.8231
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5174 - accuracy: 0.8395 - val_loss: 0.4623 - val_accuracy: 0.8609
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4694 - accuracy: 0.8593 - val_loss: 0.4382 - val_accuracy: 0.8714
# Performing experiment for epsilon = 0.1
# Epoch 1/3
# 224/224 [==============================] - 5s 19ms/step - loss: 0.9353 - accuracy: 0.7243 - val_loss: 0.5417 - val_accuracy: 0.8359
# Epoch 2/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.5093 - accuracy: 0.8434 - val_loss: 0.4628 - val_accuracy: 0.8553
# Epoch 3/3
# 224/224 [==============================] - 4s 19ms/step - loss: 0.4710 - accuracy: 0.8559 - val_loss: 0.4373 - val_accuracy: 0.8680

# %%
np.save('dpsgd_acc_n_n2000', acc_n)


gaussian_n = np.load('./data/acc_output_n_gaussian.npy')
gaussian_arr_n = np.load('./data/n_arr_gaussian.npy')

plt.rcParams.update({'font.size': 28})
fig, ax1 = plt.subplots()
fig.set_size_inches(16, 9)
color = 'tab:red'
ax1.set_xlabel('n')
ax1.set_ylabel('Accuracy', color=color)
ax1.plot(N, acc_n, color=color, linestyle='--', marker='x', linewidth=3, label='$(0.1, 10^{{-5}})$-DP-SGD')
ax1.plot(gaussian_arr_n, gaussian_n, color='blue', linestyle='-.', marker='x', linewidth=3, label=fr"$(5, 10^{{-5}})$-DP output pert.")
#ax1.plot(N, acc_output, color=color, linestyle='-.', marker='o',linewidth=3, label='output')
ax1.plot(N, non_priv_acc, color='green', linestyle='-',linewidth=3, label='non private')
ax1.tick_params(axis='y', labelcolor=color)
plt.title(fr"Accuracy for different $n$ and fixed $\epsilon_p$")
plt.legend(loc='lower right')
plt.savefig('./data/acc_n_dp_sgd_T3')
